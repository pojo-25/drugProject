# %% [markdown]
# <a href="https://colab.research.google.com/github/pojo-25/drugProject/blob/branchProjectTrial0/SequenceModelToProjectDenemeTox21SR-ATAD5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, cohen_kappa_score, f1_score, confusion_matrix
import numpy as np

# %%
# data_path = '/content/data/HIV.csv'
# col_smiles = 'smiles'
# col_target = 'HIV_active'


# # read data
# df = pd.read_csv(data_path, sep=',')
# df_no_na = df[[col_smiles, col_target]].dropna()

# X = df_no_na[col_smiles]
# y = df_no_na[col_target].values

# print(X)

# %%
# col_smiles = 'canonical_smiles'
# col_target = 'bioactivity_class'

col_smiles = 'smiles'
col_target = 'SR-ATAD5'


METRIC_ACCURACY = 'accuracy'
METRIC_F1_SCORE = 'f1-score'
METRIC_COHEN_KAPPA = 'Cohen kappa'
METRIC_CONFUSION_MATRIX = 'Confusion Matrix'


CLASSES = ['benign', 'malignant']
TEST_RATIO = 0.3
SEED = 0

#data_path = '/content/data/abl_kinase-data.csv'
#data_path = '/content/data/HIV.csv'
data_path = '/content/data/tox21.csv'

# %%
def read_data(data_path, col_smiles='smiles', col_target='SR-ATAD5'):
    """Split original data into train data and test data.
    :param data_path: str, path to the a CSV data file
    :param col_smiles: str, name of smiles column
    :param col_target: str, name of target column
    :param test_ratio: float, proportion of the original data for testset, must be from 0 to 1
    :param seed: int, randomization seed for reproducibility
    :return (X, y)
    """
    

    # read data
    df = pd.read_csv(data_path, sep=',')
    df_no_na = df[[col_smiles, col_target]].dropna()

    X = df_no_na[col_smiles]
    y = df_no_na[col_target].values

    # df['new_Bio'] = pd.factorize(df.bioactivity_class)[0]

    # df.head()

    # y = df['new_Bio'].values

    return X, y

                
def get_prediction_score(y_label, y_predict):
    """Evaluate predictions using different evaluation metrics.
    :param y_label: list, contains true label
    :param y_predict: list, contains predicted label
    :return scores: dict, evaluation metrics on the prediction
    """
    scores = {}
    scores[METRIC_ACCURACY] = accuracy_score(y_label, y_predict)
    scores[METRIC_F1_SCORE] = f1_score(y_label, y_predict, labels=None, average='macro', sample_weight=None)
    scores[METRIC_COHEN_KAPPA] = cohen_kappa_score(y_label, y_predict)
    scores[METRIC_CONFUSION_MATRIX] = confusion_matrix(y_label, y_predict)
    
    return scores

# %%
import os
import sys
sys.path.insert(0, os.getcwd()) # add current working directory to pythonpath



import tensorflow as tf

from tensorflow.python.keras import backend as K
#os.environ["CUDA_VISIBLE_DEVICES"]="0" # Use only the 1st GPU
tf_config = tf.compat.v1.ConfigProto()
sess = tf.compat.v1.Session(config=tf_config)
K.set_session(sess)


from tensorflow.keras import callbacks
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Flatten
from tensorflow.keras.layers import Embedding, LSTM, GlobalMaxPooling1D, SpatialDropout1D, Conv1D, MaxPooling1D, GRU, Bidirectional
from tensorflow.keras import optimizers
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight


import warnings
import gc

# %%
# import os
# import sys
# sys.path.insert(0, os.getcwd()) # add current working directory to pythonpath



# import keras.backend as K
# import numpy as np
# import tensorflow as tf
# from keras import callbacks
# from keras.optimizers import Adam
# from keras.models import load_model
# from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
# from keras.models import Sequential
# from keras.models import Model
# from keras.layers import Input, Dense, Dropout, BatchNormalization, Flatten
# from keras.layers import Embedding, LSTM, GlobalMaxPooling1D, SpatialDropout1D, Conv1D, MaxPooling1D, GRU, Bidirectional
# from keras import optimizers
# from sklearn.model_selection import train_test_split
# from sklearn.utils import class_weight

# import warnings
# import argparse
# import gc

# %%
def generate_tokens(smiles, len_percentile=100):
    """
    Generate character tokens from smiles
    :param smiles: Pandas series, containing smiles
    :param len_percentile: percentile of smiles length to set as max length
    :return tokens
    :return num_words
    :return max_phrase_len
    """ 
    
    # Get max length of smiles
    smiles_len = smiles.apply(lambda p: len(p))
    max_phrase_len = int(np.percentile(smiles_len, len_percentile))
    print('True max length is ' + str(np.max(smiles_len)) + ', ' + str(max_phrase_len) + ' is set the length cutoff.')
        
    # Get unique words
    unique_words = np.unique(np.concatenate(smiles.apply(lambda p: np.array(list(p))).values, axis=0))
    num_words = len(unique_words)
    print('Vocab size is ' + str(num_words))
    
    tokenizer = Tokenizer(
        num_words = num_words,
        filters = '$',
        char_level = True,
        oov_token = '_'
    )

    #print(num_words)
    
    tokenizer.fit_on_texts(smiles)
    sequences = tokenizer.texts_to_sequences(smiles)
    tokens = pad_sequences(sequences, maxlen = max_phrase_len, padding='post', truncating='post')
    
    return tokens, num_words, max_phrase_len

# %%
smiles, y = read_data(data_path, col_smiles='smiles', col_target='SR-MMP')
tokens, num_words, max_phrase_len = generate_tokens(smiles, len_percentile=100)
# Out:
# True max length is 325, 325 is set the length cutoff.
# Vocab size is 53

# %%
def create_model(model_type, num_words, input_length, output_dim=1, dropout_rate=0.0):
    """Build different sequence model
    :param model_type: str, can be 'cnn-gru', 'cnn', 'gru', 'lstm'
    :param num_words: int
    :param input_length: int
    :param output_dim: int
    :return model: Keras model
    """ 
    
    model = Sequential()
    if model_type == 'lstm': # LSTM - LSTM
        model.add(Embedding(num_words+1, 50, input_length=input_length))
        model.add(Bidirectional(LSTM(8, return_sequences=True)))
        model.add(Bidirectional(LSTM(16)))
        model.add(Dense(128, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(output_dim, activation='sigmoid'))
    elif model_type == 'gru': # GRU - GRU
        model.add(Embedding(num_words+1, 50, input_length=input_length))
        model.add(Bidirectional(GRU(8, return_sequences=True)))
        model.add(Bidirectional(GRU(16)))
        model.add(Dense(128, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(output_dim, activation='sigmoid'))
    elif model_type == 'cnn-gru': # 1D CNN - GRU
        model.add(Embedding(num_words+1, 50, input_length=input_length))
        model.add(Conv1D(8,3,activation='relu'))
        model.add(Bidirectional(GRU(16, return_sequences=True)))
        model.add(Bidirectional(GRU(32)))
        model.add(Dense(64, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(output_dim, activation='sigmoid'))
    elif model_type == 'cnn': # 1D CNN
        model.add(Embedding(num_words+1, 50, input_length=input_length))
        model.add(Conv1D(192, 10, activation='relu'))
        model.add(BatchNormalization())
        model.add(Conv1D(192, 3, activation='relu'))
        model.add(Flatten())
        model.add(Dense(128, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(output_dim, activation='sigmoid'))
    # elif model_type == 'cnn-lstm': # 1D CNN - LSTM
    #     model.add(Embedding(num_words+1, 50, input_length=input_length))
    #     model.add(Conv1D(192,3,activation='relu'))
    #     model.add(Bidirectional(LSTM(224, return_sequences=True)))
    #     model.add(Bidirectional(LSTM(384)))
    #     model.add(Dense(128, activation='relu'))
    #     model.add(Dropout(dropout_rate))
    #     model.add(Dense(output_dim, activation='sigmoid'))
    else:
        #raise ValueError(model_type + ' is not supported.')
        print('wrong model')
 
    model.summary()    
    return model

# %%
# def build_sequence_model(trainset, testset, model_type, num_words, input_length, output_dim=1, dropout_rate=0.0,
#                      batch_size=32, nb_epochs=100, lr=0.001):
#     """Train and evaluate CNN model
#     :param trainset: (X_train, y_train)
#     :param testset: (X_test, y_test)
#     :param model_type: str, can be 'cnn-gru', 'cnn', 'gru', 'lstm'
#     :param num_words: int
#     :param input_length: int
#     :param output_dim: int
#     :param batch_size: int, batch size for model training
#     :param nb_epochs: int, number of training epoches
#     :param lr: float, learning rate
#     :param save_path: path to save model
#     :return model: fitted Keras model
#     :return scores: dict, scores on test set for the fitted Keras model
#     """
    
#     # Create model
#     model = create_model(model_type=model_type, num_words=num_words, input_length=input_length, output_dim=output_dim,
#                          dropout_rate=dropout_rate)
    
#     # Callback list
#     callback_list = []
#     # monitor val_loss and terminate training if no improvement
#     early_stop = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.00001, \
#                 patience=20, verbose=2, mode='auto', restore_best_weights=True)
#     callback_list.append(early_stop)
    
#     # if save_path is not None:
#     #     # save best model based on val_acc during training
#     #     checkpoint = callbacks.ModelCheckpoint(os.path.join(save_path, '.h5'), monitor='val_acc', \
#     #                 verbose=0, save_best_only=True, save_weights_only=False, mode='auto')
#     #     callback_list.append(checkpoint)
        
#     # Get train and test set
#     (X_train, y_train) = trainset
#     (X_test, y_test) = testset
    
#     # Compute class weights
#     weight_list = class_weight.compute_class_weight('balanced', np.unique(y_train), y_train)
#     weight_dict = {}
#     for i in range(len(np.unique(y_train))):
#         weight_dict[np.unique(y_train)[i]] = weight_list[i]
    
#     # Train only classification head
#     optimizer = Adam(lr=lr, decay=1e-6, momentum=0.9, nesterov=True)
#     model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
#     model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=nb_epochs, \
#                         class_weight=weight_dict, callbacks=callback_list, verbose=2)
    
#     # Evaluate model    
#     prediction = model.predict(X_test)
#     y_val_predict = (prediction > 0.5).astype('uint8')
#     with warnings.catch_warnings():
#         warnings.simplefilter('ignore')  # disable the warning on f1-score with not all labels
#         scores = get_prediction_score(y_val, y_val_predict)
        
#     return model, scores

# %%
import matplotlib.pyplot as plt

# %%
def build_sequence_model(trainset, testset, model_type, num_words, input_length, output_dim=1, dropout_rate=0.0,
                     batch_size=32, nb_epochs=100, lr=0.001,
                     save_path=None):
    """Train and evaluate CNN model
    :param trainset: (X_train, y_train)
    :param testset: (X_test, y_test)
    :param model_type: str, can be 'cnn-gru', 'cnn', 'gru', 'lstm'
    :param num_words: int
    :param input_length: int
    :param output_dim: int
    :param batch_size: int, batch size for model training
    :param nb_epochs: int, number of training epoches
    :param lr: float, learning rate
    :param save_path: path to save model
    :return model: fitted Keras model
    :return scores: dict, scores on test set for the fitted Keras model
    """
    
    # Create model
    model = create_model(model_type=model_type, num_words=num_words, input_length=input_length, output_dim=output_dim,
                         dropout_rate=dropout_rate)
    
    # Callback list
    callback_list = []
    # monitor val_loss and terminate training if no improvement
    early_stop = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.00001, \
                patience=20, verbose=2, mode='auto', restore_best_weights=True)
    callback_list.append(early_stop)
    
    if save_path is not None:
        # save best model based on val_acc during training
        checkpoint = callbacks.ModelCheckpoint(os.path.join(save_path, model_type + '.h5'), monitor='val_acc', \
                    verbose=0, save_best_only=True, save_weights_only=False, mode='auto')
        callback_list.append(checkpoint)
        
    # Get train and test set
    (X_train, y_train) = trainset
    (X_test, y_test) = testset
    
    # Compute class weights
    weight_list = class_weight.compute_class_weight('balanced', np.unique(y_train), y_train)
    weight_dict = {}
    for i in range(len(np.unique(y_train))):
        weight_dict[np.unique(y_train)[i]] = weight_list[i]
    
    # Train only classification head
    optimizer = Adam(lr=lr, decay=1e-6)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=nb_epochs, \
                        class_weight=weight_dict, callbacks=callback_list, verbose=2)
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

        
    # Evaluate model    
    prediction = model.predict(X_test)
    y_val_predict = (prediction > 0.5).astype('uint8')
    y_val = y_test
    with warnings.catch_warnings():
        warnings.filterwarnings('ignore')  # disable the warning on f1-score with not all labels
        scores = get_prediction_score(y_val, y_val_predict)
        
    return model, scores

# %%
#data_path = '/content/data/abl_kinase-data.csv'
#data_path = '/content/data/HIV.csv'
data_path = '/content/data/tox21.csv'




#, 'cnn-gru', 'gru', 'lstm'
model_list = ['cnn', 'cnn-gru', 'gru', 'lstm']
batch_size = 16
nb_epochs = 100
lr = 0.001
save_path = '/content/data'

WORK_DIRECTORY = '/content/data'

# Make save_path
# if save_path is not None:
#     os.makedirs(os.path.join(save_path, 'sequence_models'), exist_ok=True)

# Read data
smiles, y = read_data(data_path, col_smiles='smiles', col_target='SR-ATAD5')
tokens, num_words, max_phrase_len = generate_tokens(smiles, len_percentile=100)

# Get train and test set
X_train, X_test, y_train, y_test = train_test_split(tokens, y, test_size=TEST_RATIO, shuffle=True, stratify=y,
                                                  random_state=SEED)

# Build en evaluate graph models
model_scores = []
for model_type in model_list:
    model, scores = build_sequence_model((X_train, y_train), (X_test, y_test), model_type, num_words, max_phrase_len,
                                          output_dim=1, dropout_rate=0.0,
                                          batch_size=batch_size, nb_epochs=nb_epochs, lr=lr,
                             save_path=os.path.join(save_path, 'sequence_models', model_type + '.h5'))
    model_scores.append(scores)
        
    # force release memory
    K.clear_session()
    del model
    gc.collect()

model_df = pd.DataFrame({'model': model_list,

                    METRIC_ACCURACY: [score[METRIC_ACCURACY] for score in model_scores],
                    METRIC_F1_SCORE: [score[METRIC_F1_SCORE] for score in model_scores],
                    METRIC_COHEN_KAPPA: [score[METRIC_COHEN_KAPPA] for score in model_scores],
                    METRIC_CONFUSION_MATRIX: [score[METRIC_CONFUSION_MATRIX] for score in model_scores]                            
                      })
model_df = model_df[['model', METRIC_ACCURACY, METRIC_F1_SCORE, METRIC_COHEN_KAPPA,
                      METRIC_CONFUSION_MATRIX]]


model_df.to_csv(os.path.join(WORK_DIRECTORY, 'summary_sequence_model.csv'), index=False)
model_df.sort_values(by=[METRIC_ACCURACY, METRIC_F1_SCORE, METRIC_COHEN_KAPPA],
                      ascending=False, inplace=True)
print('Best model:\n' + str(model_df.iloc[0]))

print(model_df)



# !cp -r /content/data /content/drive/MyDrive/sequenceModelResults0
# Out:
# True max length is 342, 342 is set the length cutoff.
# Vocab size is 55
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 342, 50)           2800
# _________________________________________________________________
# conv1d (Conv1D)              (None, 333, 192)          96192
# _________________________________________________________________
# batch_normalization (BatchNo (None, 333, 192)          768
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 331, 192)          110784
# _________________________________________________________________
# flatten (Flatten)            (None, 63552)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               8134784
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 8,345,457
# Trainable params: 8,345,073
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 155/155 - 3s - loss: 0.7829 - accuracy: 0.5224 - val_loss: 0.6931 - val_accuracy: 0.5231
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 155/155 - 2s - loss: 0.6302 - accuracy: 0.6438 - val_loss: 0.6822 - val_accuracy: 0.8940
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 155/155 - 2s - loss: 0.5414 - accuracy: 0.7295 - val_loss: 0.5361 - val_accuracy: 0.8016
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 155/155 - 2s - loss: 0.4441 - accuracy: 0.7840 - val_loss: 0.3593 - val_accuracy: 0.8648
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 155/155 - 2s - loss: 0.3111 - accuracy: 0.8675 - val_loss: 0.3184 - val_accuracy: 0.9618
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 155/155 - 2s - loss: 0.2160 - accuracy: 0.8976 - val_loss: 0.2678 - val_accuracy: 0.9397
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 155/155 - 2s - loss: 0.2380 - accuracy: 0.8990 - val_loss: 0.3491 - val_accuracy: 0.8916
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 155/155 - 2s - loss: 0.1478 - accuracy: 0.9390 - val_loss: 0.3099 - val_accuracy: 0.9133
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 155/155 - 2s - loss: 0.1020 - accuracy: 0.9584 - val_loss: 0.3162 - val_accuracy: 0.9519
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 155/155 - 2s - loss: 0.1035 - accuracy: 0.9529 - val_loss: 0.4075 - val_accuracy: 0.8916
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 155/155 - 2s - loss: 0.1406 - accuracy: 0.9531 - val_loss: 1.5894 - val_accuracy: 0.5410
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 155/155 - 2s - loss: 0.0979 - accuracy: 0.9614 - val_loss: 0.3850 - val_accuracy: 0.9614
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 155/155 - 2s - loss: 0.0650 - accuracy: 0.9743 - val_loss: 0.4092 - val_accuracy: 0.9274
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 155/155 - 2s - loss: 0.0404 - accuracy: 0.9822 - val_loss: 0.3788 - val_accuracy: 0.9373
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 155/155 - 2s - loss: 0.0294 - accuracy: 0.9905 - val_loss: 0.5014 - val_accuracy: 0.9383
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 155/155 - 2s - loss: 0.0362 - accuracy: 0.9877 - val_loss: 0.4999 - val_accuracy: 0.9185
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 155/155 - 2s - loss: 0.0488 - accuracy: 0.9851 - val_loss: 0.4405 - val_accuracy: 0.9453
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 155/155 - 2s - loss: 0.0482 - accuracy: 0.9806 - val_loss: 0.4189 - val_accuracy: 0.9208
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 155/155 - 2s - loss: 0.0207 - accuracy: 0.9921 - val_loss: 0.3928 - val_accuracy: 0.9453
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 155/155 - 2s - loss: 0.0786 - accuracy: 0.9846 - val_loss: 0.5405 - val_accuracy: 0.9533
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 155/155 - 2s - loss: 0.1241 - accuracy: 0.9630 - val_loss: 0.5815 - val_accuracy: 0.9354
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 155/155 - 2s - loss: 0.1250 - accuracy: 0.9699 - val_loss: 0.4149 - val_accuracy: 0.9331
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 155/155 - 2s - loss: 0.1140 - accuracy: 0.9616 - val_loss: 0.4469 - val_accuracy: 0.9189
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# 155/155 - 2s - loss: 0.0847 - accuracy: 0.9719 - val_loss: 0.5694 - val_accuracy: 0.9166
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# 155/155 - 2s - loss: 0.1274 - accuracy: 0.9685 - val_loss: 0.6645 - val_accuracy: 0.8926
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# 155/155 - 2s - loss: 0.1195 - accuracy: 0.9638 - val_loss: 0.3670 - val_accuracy: 0.9293
# Restoring model weights from the end of the best epoch.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00026: early stopping
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 342, 50)           2800
# _________________________________________________________________
# conv1d (Conv1D)              (None, 340, 8)            1208
# _________________________________________________________________
# bidirectional (Bidirectional (None, 340, 32)           2496
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                12672
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 23,401
# Trainable params: 23,401
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 155/155 - 13s - loss: 0.6941 - accuracy: 0.7481 - val_loss: 0.7139 - val_accuracy: 0.0575
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 155/155 - 7s - loss: 0.6779 - accuracy: 0.5653 - val_loss: 0.6369 - val_accuracy: 0.6480
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 155/155 - 7s - loss: 0.6566 - accuracy: 0.6040 - val_loss: 0.7443 - val_accuracy: 0.5254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 155/155 - 7s - loss: 0.6431 - accuracy: 0.5733 - val_loss: 0.6661 - val_accuracy: 0.5570
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 155/155 - 7s - loss: 0.6413 - accuracy: 0.5681 - val_loss: 0.8338 - val_accuracy: 0.3148
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 155/155 - 7s - loss: 0.6188 - accuracy: 0.6036 - val_loss: 0.5297 - val_accuracy: 0.7059
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 155/155 - 7s - loss: 0.5974 - accuracy: 0.6240 - val_loss: 0.5287 - val_accuracy: 0.6861
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 155/155 - 7s - loss: 0.6047 - accuracy: 0.5604 - val_loss: 0.4458 - val_accuracy: 0.7347
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 155/155 - 7s - loss: 0.5714 - accuracy: 0.6394 - val_loss: 0.5236 - val_accuracy: 0.6871
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 155/155 - 7s - loss: 0.5665 - accuracy: 0.6545 - val_loss: 0.5871 - val_accuracy: 0.6334
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 155/155 - 7s - loss: 0.5384 - accuracy: 0.6630 - val_loss: 0.5466 - val_accuracy: 0.6550
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 155/155 - 7s - loss: 0.5333 - accuracy: 0.6653 - val_loss: 0.6518 - val_accuracy: 0.5481
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 155/155 - 7s - loss: 0.5097 - accuracy: 0.6525 - val_loss: 0.3660 - val_accuracy: 0.7945
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 155/155 - 7s - loss: 0.4951 - accuracy: 0.6859 - val_loss: 0.3697 - val_accuracy: 0.8021
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 155/155 - 7s - loss: 0.5007 - accuracy: 0.6760 - val_loss: 0.7477 - val_accuracy: 0.4976
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 155/155 - 7s - loss: 0.4895 - accuracy: 0.6653 - val_loss: 0.5998 - val_accuracy: 0.6173
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 155/155 - 7s - loss: 0.4752 - accuracy: 0.6832 - val_loss: 0.5182 - val_accuracy: 0.6730
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 155/155 - 7s - loss: 0.4760 - accuracy: 0.6754 - val_loss: 0.5411 - val_accuracy: 0.6626
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 155/155 - 7s - loss: 0.4411 - accuracy: 0.7014 - val_loss: 0.4152 - val_accuracy: 0.7498
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 155/155 - 7s - loss: 0.4511 - accuracy: 0.6956 - val_loss: 0.4381 - val_accuracy: 0.7220
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 155/155 - 7s - loss: 0.4392 - accuracy: 0.7089 - val_loss: 0.3824 - val_accuracy: 0.7795
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 155/155 - 7s - loss: 0.4457 - accuracy: 0.6966 - val_loss: 0.6224 - val_accuracy: 0.5745
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 155/155 - 7s - loss: 0.4501 - accuracy: 0.7147 - val_loss: 0.5588 - val_accuracy: 0.6687
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# 155/155 - 7s - loss: 0.4473 - accuracy: 0.6782 - val_loss: 0.4864 - val_accuracy: 0.6880
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# 155/155 - 7s - loss: 0.4199 - accuracy: 0.7180 - val_loss: 0.4316 - val_accuracy: 0.7356
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# 155/155 - 7s - loss: 0.4431 - accuracy: 0.6887 - val_loss: 0.6799 - val_accuracy: 0.5514
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/100
# 155/155 - 7s - loss: 0.4124 - accuracy: 0.7382 - val_loss: 0.6036 - val_accuracy: 0.6541
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/100
# 155/155 - 7s - loss: 0.4045 - accuracy: 0.7275 - val_loss: 0.4078 - val_accuracy: 0.7719
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/100
# 155/155 - 7s - loss: 0.4045 - accuracy: 0.7333 - val_loss: 0.5861 - val_accuracy: 0.6442
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/100
# 155/155 - 7s - loss: 0.4187 - accuracy: 0.7208 - val_loss: 0.4320 - val_accuracy: 0.7446
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 31/100
# 155/155 - 7s - loss: 0.3974 - accuracy: 0.7479 - val_loss: 0.8662 - val_accuracy: 0.4713
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 32/100
# 155/155 - 7s - loss: 0.4123 - accuracy: 0.7139 - val_loss: 0.3803 - val_accuracy: 0.7879
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 33/100
# 155/155 - 7s - loss: 0.3701 - accuracy: 0.7626 - val_loss: 0.4807 - val_accuracy: 0.7205
# Restoring model weights from the end of the best epoch.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00033: early stopping
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 342, 50)           2800
# _________________________________________________________________
# bidirectional (Bidirectional (None, 342, 16)           2880
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 32)                3264
# _________________________________________________________________
# dense (Dense)                (None, 128)               4224
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 13,297
# Trainable params: 13,297
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 155/155 - 13s - loss: 0.6926 - accuracy: 0.4166 - val_loss: 0.6565 - val_accuracy: 0.8558
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 155/155 - 7s - loss: 0.6826 - accuracy: 0.5707 - val_loss: 0.6297 - val_accuracy: 0.6268
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 155/155 - 7s - loss: 0.6740 - accuracy: 0.5626 - val_loss: 0.5701 - val_accuracy: 0.7083
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 155/155 - 7s - loss: 0.6614 - accuracy: 0.5248 - val_loss: 0.5095 - val_accuracy: 0.7116
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 155/155 - 7s - loss: 0.6537 - accuracy: 0.5238 - val_loss: 0.6466 - val_accuracy: 0.5424
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 155/155 - 7s - loss: 0.6369 - accuracy: 0.5202 - val_loss: 0.5791 - val_accuracy: 0.6390
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 155/155 - 7s - loss: 0.6256 - accuracy: 0.5695 - val_loss: 0.7508 - val_accuracy: 0.5014
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 155/155 - 7s - loss: 0.6178 - accuracy: 0.5891 - val_loss: 0.5506 - val_accuracy: 0.6395
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 155/155 - 7s - loss: 0.6129 - accuracy: 0.5752 - val_loss: 0.6997 - val_accuracy: 0.5019
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 155/155 - 7s - loss: 0.6081 - accuracy: 0.5786 - val_loss: 0.6897 - val_accuracy: 0.4873
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 155/155 - 7s - loss: 0.6068 - accuracy: 0.5747 - val_loss: 0.4763 - val_accuracy: 0.7022
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 155/155 - 7s - loss: 0.6058 - accuracy: 0.5507 - val_loss: 0.4908 - val_accuracy: 0.6970
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 155/155 - 7s - loss: 0.5974 - accuracy: 0.5752 - val_loss: 0.6368 - val_accuracy: 0.5452
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 155/155 - 7s - loss: 0.5837 - accuracy: 0.5980 - val_loss: 0.6219 - val_accuracy: 0.5975
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 155/155 - 7s - loss: 0.5799 - accuracy: 0.6105 - val_loss: 0.6813 - val_accuracy: 0.5311
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 155/155 - 7s - loss: 0.5730 - accuracy: 0.5820 - val_loss: 0.5745 - val_accuracy: 0.6117
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 155/155 - 7s - loss: 0.5669 - accuracy: 0.6101 - val_loss: 0.5019 - val_accuracy: 0.6781
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 155/155 - 7s - loss: 0.5586 - accuracy: 0.6190 - val_loss: 0.5411 - val_accuracy: 0.6263
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 155/155 - 7s - loss: 0.5613 - accuracy: 0.5806 - val_loss: 0.5117 - val_accuracy: 0.6626
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 155/155 - 7s - loss: 0.5573 - accuracy: 0.6448 - val_loss: 0.5594 - val_accuracy: 0.6254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 155/155 - 7s - loss: 0.5438 - accuracy: 0.6190 - val_loss: 0.6204 - val_accuracy: 0.5754
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 155/155 - 7s - loss: 0.5312 - accuracy: 0.6374 - val_loss: 0.6075 - val_accuracy: 0.5877
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 155/155 - 7s - loss: 0.5277 - accuracy: 0.6400 - val_loss: 0.7363 - val_accuracy: 0.5028
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# 155/155 - 7s - loss: 0.5277 - accuracy: 0.6291 - val_loss: 0.6376 - val_accuracy: 0.5693
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# 155/155 - 7s - loss: 0.5123 - accuracy: 0.6345 - val_loss: 0.4987 - val_accuracy: 0.6635
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# 155/155 - 7s - loss: 0.5125 - accuracy: 0.6521 - val_loss: 0.4922 - val_accuracy: 0.6852
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/100
# 155/155 - 7s - loss: 0.5051 - accuracy: 0.6420 - val_loss: 0.5355 - val_accuracy: 0.6461
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/100
# 155/155 - 7s - loss: 0.5025 - accuracy: 0.6531 - val_loss: 0.5006 - val_accuracy: 0.6762
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/100
# 155/155 - 7s - loss: 0.4955 - accuracy: 0.6661 - val_loss: 0.4699 - val_accuracy: 0.7008
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/100
# 155/155 - 7s - loss: 0.4988 - accuracy: 0.6715 - val_loss: 0.6643 - val_accuracy: 0.5617
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 31/100
# 155/155 - 7s - loss: 0.4866 - accuracy: 0.6624 - val_loss: 0.6095 - val_accuracy: 0.5980
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 32/100
# 155/155 - 7s - loss: 0.4760 - accuracy: 0.6705 - val_loss: 0.5686 - val_accuracy: 0.6404
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 33/100
# 155/155 - 7s - loss: 0.4700 - accuracy: 0.6828 - val_loss: 0.4865 - val_accuracy: 0.6857
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 34/100
# 155/155 - 7s - loss: 0.4567 - accuracy: 0.6933 - val_loss: 0.4458 - val_accuracy: 0.7177
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 35/100
# 155/155 - 7s - loss: 0.4537 - accuracy: 0.6923 - val_loss: 0.4329 - val_accuracy: 0.7238
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 36/100
# 155/155 - 7s - loss: 0.4546 - accuracy: 0.6758 - val_loss: 0.4225 - val_accuracy: 0.7309
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 37/100
# 155/155 - 7s - loss: 0.4539 - accuracy: 0.6842 - val_loss: 0.4823 - val_accuracy: 0.6833
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 38/100
# 155/155 - 7s - loss: 0.4530 - accuracy: 0.7000 - val_loss: 0.4872 - val_accuracy: 0.6993
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 39/100
# 155/155 - 7s - loss: 0.4343 - accuracy: 0.7030 - val_loss: 0.5041 - val_accuracy: 0.6777
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 40/100
# 155/155 - 7s - loss: 0.4368 - accuracy: 0.7178 - val_loss: 0.5554 - val_accuracy: 0.6602
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 41/100
# 155/155 - 7s - loss: 0.4225 - accuracy: 0.7046 - val_loss: 0.4857 - val_accuracy: 0.7092
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 42/100
# 155/155 - 7s - loss: 0.4168 - accuracy: 0.7154 - val_loss: 0.5297 - val_accuracy: 0.6852
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 43/100
# 155/155 - 7s - loss: 0.4172 - accuracy: 0.7178 - val_loss: 0.5367 - val_accuracy: 0.6451
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 44/100
# 155/155 - 7s - loss: 0.4099 - accuracy: 0.7222 - val_loss: 0.4699 - val_accuracy: 0.7097
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 45/100
# 155/155 - 7s - loss: 0.4008 - accuracy: 0.7337 - val_loss: 0.4846 - val_accuracy: 0.6918
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 46/100
# 155/155 - 7s - loss: 0.3863 - accuracy: 0.7311 - val_loss: 0.4957 - val_accuracy: 0.6993
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 47/100
# 155/155 - 7s - loss: 0.3859 - accuracy: 0.7376 - val_loss: 0.4371 - val_accuracy: 0.7422
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 48/100
# 155/155 - 7s - loss: 0.3799 - accuracy: 0.7422 - val_loss: 0.4818 - val_accuracy: 0.7078
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 49/100
# 155/155 - 7s - loss: 0.3679 - accuracy: 0.7467 - val_loss: 0.4163 - val_accuracy: 0.7559
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 50/100
# 155/155 - 7s - loss: 0.3822 - accuracy: 0.7507 - val_loss: 0.5305 - val_accuracy: 0.6725
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 51/100
# 155/155 - 7s - loss: 0.3652 - accuracy: 0.7400 - val_loss: 0.4298 - val_accuracy: 0.7427
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 52/100
# 155/155 - 7s - loss: 0.3488 - accuracy: 0.7608 - val_loss: 0.5959 - val_accuracy: 0.6546
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 53/100
# 155/155 - 7s - loss: 0.3641 - accuracy: 0.7442 - val_loss: 0.4108 - val_accuracy: 0.7601
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 54/100
# 155/155 - 7s - loss: 0.3543 - accuracy: 0.7487 - val_loss: 0.4929 - val_accuracy: 0.7238
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 55/100
# 155/155 - 7s - loss: 0.3317 - accuracy: 0.7675 - val_loss: 0.3993 - val_accuracy: 0.7785
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 56/100
# 155/155 - 7s - loss: 0.3509 - accuracy: 0.7529 - val_loss: 0.5292 - val_accuracy: 0.6833
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 57/100
# 155/155 - 7s - loss: 0.3304 - accuracy: 0.7723 - val_loss: 0.4209 - val_accuracy: 0.7648
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 58/100
# 155/155 - 7s - loss: 0.3448 - accuracy: 0.7461 - val_loss: 0.5195 - val_accuracy: 0.7366
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 59/100
# 155/155 - 7s - loss: 0.3461 - accuracy: 0.7513 - val_loss: 0.4799 - val_accuracy: 0.7304
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 60/100
# 155/155 - 7s - loss: 0.3170 - accuracy: 0.7747 - val_loss: 0.5511 - val_accuracy: 0.6739
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 61/100
# 155/155 - 7s - loss: 0.3272 - accuracy: 0.7661 - val_loss: 0.3493 - val_accuracy: 0.8148
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 62/100
# 155/155 - 7s - loss: 0.3229 - accuracy: 0.7739 - val_loss: 0.4098 - val_accuracy: 0.7658
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 63/100
# 155/155 - 7s - loss: 0.3227 - accuracy: 0.7628 - val_loss: 0.4458 - val_accuracy: 0.7710
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 64/100
# 155/155 - 7s - loss: 0.3005 - accuracy: 0.7832 - val_loss: 0.3820 - val_accuracy: 0.8073
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 65/100
# 155/155 - 7s - loss: 0.2847 - accuracy: 0.7962 - val_loss: 0.4252 - val_accuracy: 0.7743
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 66/100
# 155/155 - 7s - loss: 0.2973 - accuracy: 0.7903 - val_loss: 0.4839 - val_accuracy: 0.7446
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 67/100
# 155/155 - 7s - loss: 0.3117 - accuracy: 0.7800 - val_loss: 0.7355 - val_accuracy: 0.6098
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 68/100
# 155/155 - 7s - loss: 0.3358 - accuracy: 0.7434 - val_loss: 0.4606 - val_accuracy: 0.7493
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 69/100
# 155/155 - 7s - loss: 0.3250 - accuracy: 0.7646 - val_loss: 0.4791 - val_accuracy: 0.7328
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 70/100
# 155/155 - 7s - loss: 0.2881 - accuracy: 0.7927 - val_loss: 0.4082 - val_accuracy: 0.7837
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 71/100
# 155/155 - 7s - loss: 0.3045 - accuracy: 0.7869 - val_loss: 0.4358 - val_accuracy: 0.7592
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 72/100
# 155/155 - 7s - loss: 0.2818 - accuracy: 0.8022 - val_loss: 0.4339 - val_accuracy: 0.7861
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 73/100
# 155/155 - 7s - loss: 0.2591 - accuracy: 0.8131 - val_loss: 0.3965 - val_accuracy: 0.8172
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 74/100
# 155/155 - 7s - loss: 0.2442 - accuracy: 0.8307 - val_loss: 0.4355 - val_accuracy: 0.7936
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 75/100
# 155/155 - 7s - loss: 0.2706 - accuracy: 0.8063 - val_loss: 0.4126 - val_accuracy: 0.8101
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 76/100
# 155/155 - 7s - loss: 0.2560 - accuracy: 0.8228 - val_loss: 0.5253 - val_accuracy: 0.7502
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 77/100
# 155/155 - 7s - loss: 0.2771 - accuracy: 0.8040 - val_loss: 0.4942 - val_accuracy: 0.7582
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 78/100
# 155/155 - 7s - loss: 0.2752 - accuracy: 0.7982 - val_loss: 0.4390 - val_accuracy: 0.7884
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 79/100
# 155/155 - 7s - loss: 0.2363 - accuracy: 0.8273 - val_loss: 0.4875 - val_accuracy: 0.7875
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 80/100
# 155/155 - 7s - loss: 0.2796 - accuracy: 0.8032 - val_loss: 0.4360 - val_accuracy: 0.7592
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 81/100
# 155/155 - 7s - loss: 0.2674 - accuracy: 0.8162 - val_loss: 0.4762 - val_accuracy: 0.7747
# Restoring model weights from the end of the best epoch.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00081: early stopping
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 342, 50)           2800
# _________________________________________________________________
# bidirectional (Bidirectional (None, 342, 16)           3776
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 32)                4224
# _________________________________________________________________
# dense (Dense)                (None, 128)               4224
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 15,153
# Trainable params: 15,153
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 155/155 - 13s - loss: 0.6884 - accuracy: 0.7178 - val_loss: 0.5765 - val_accuracy: 0.7036
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 155/155 - 7s - loss: 0.6635 - accuracy: 0.5307 - val_loss: 0.7197 - val_accuracy: 0.4194
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 155/155 - 7s - loss: 0.6516 - accuracy: 0.5115 - val_loss: 0.6391 - val_accuracy: 0.5434
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 155/155 - 7s - loss: 0.6395 - accuracy: 0.5812 - val_loss: 0.5628 - val_accuracy: 0.6202
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 155/155 - 7s - loss: 0.6310 - accuracy: 0.5911 - val_loss: 0.6285 - val_accuracy: 0.6041
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 155/155 - 7s - loss: 0.6245 - accuracy: 0.6004 - val_loss: 0.6172 - val_accuracy: 0.5683
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 155/155 - 7s - loss: 0.6225 - accuracy: 0.5737 - val_loss: 0.5950 - val_accuracy: 0.6136
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 155/155 - 7s - loss: 0.6133 - accuracy: 0.6154 - val_loss: 0.6840 - val_accuracy: 0.5773
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 155/155 - 7s - loss: 0.6139 - accuracy: 0.6093 - val_loss: 0.6000 - val_accuracy: 0.6343
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 155/155 - 7s - loss: 0.6029 - accuracy: 0.6436 - val_loss: 0.6906 - val_accuracy: 0.4995
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 155/155 - 7s - loss: 0.5955 - accuracy: 0.6226 - val_loss: 0.6171 - val_accuracy: 0.6230
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 155/155 - 7s - loss: 0.5980 - accuracy: 0.5899 - val_loss: 0.7011 - val_accuracy: 0.5679
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 155/155 - 7s - loss: 0.5856 - accuracy: 0.6483 - val_loss: 0.5255 - val_accuracy: 0.6748
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 155/155 - 7s - loss: 0.5783 - accuracy: 0.5986 - val_loss: 0.7386 - val_accuracy: 0.4675
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 155/155 - 7s - loss: 0.5820 - accuracy: 0.6075 - val_loss: 0.5383 - val_accuracy: 0.6805
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 155/155 - 7s - loss: 0.5710 - accuracy: 0.6707 - val_loss: 0.5868 - val_accuracy: 0.6065
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 155/155 - 7s - loss: 0.5822 - accuracy: 0.6244 - val_loss: 0.6874 - val_accuracy: 0.5198
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 155/155 - 7s - loss: 0.5667 - accuracy: 0.6162 - val_loss: 0.4368 - val_accuracy: 0.7578
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 155/155 - 7s - loss: 0.5576 - accuracy: 0.6661 - val_loss: 0.5684 - val_accuracy: 0.5537
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 155/155 - 7s - loss: 0.5730 - accuracy: 0.5156 - val_loss: 0.5485 - val_accuracy: 0.6117
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 155/155 - 7s - loss: 0.5570 - accuracy: 0.6562 - val_loss: 0.5939 - val_accuracy: 0.6239
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 155/155 - 7s - loss: 0.5473 - accuracy: 0.6406 - val_loss: 0.5291 - val_accuracy: 0.6758
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 155/155 - 7s - loss: 0.5397 - accuracy: 0.6778 - val_loss: 0.6198 - val_accuracy: 0.5801
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# 155/155 - 7s - loss: 0.5317 - accuracy: 0.6644 - val_loss: 0.4294 - val_accuracy: 0.7498
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# 155/155 - 7s - loss: 0.5163 - accuracy: 0.6865 - val_loss: 0.6436 - val_accuracy: 0.6324
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# 155/155 - 7s - loss: 0.5156 - accuracy: 0.6935 - val_loss: 0.6094 - val_accuracy: 0.5952
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/100
# 155/155 - 7s - loss: 0.5171 - accuracy: 0.6370 - val_loss: 0.5481 - val_accuracy: 0.6668
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/100
# 155/155 - 7s - loss: 0.5132 - accuracy: 0.6774 - val_loss: 0.4542 - val_accuracy: 0.7455
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/100
# 155/155 - 7s - loss: 0.5046 - accuracy: 0.6982 - val_loss: 0.6351 - val_accuracy: 0.6221
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/100
# 155/155 - 7s - loss: 0.4898 - accuracy: 0.6745 - val_loss: 0.4510 - val_accuracy: 0.7290
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 31/100
# 155/155 - 7s - loss: 0.4958 - accuracy: 0.7020 - val_loss: 0.5402 - val_accuracy: 0.6315
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 32/100
# 155/155 - 7s - loss: 0.4694 - accuracy: 0.7016 - val_loss: 0.5707 - val_accuracy: 0.6517
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 33/100
# 155/155 - 7s - loss: 0.4664 - accuracy: 0.6871 - val_loss: 0.4994 - val_accuracy: 0.6720
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 34/100
# 155/155 - 7s - loss: 0.4714 - accuracy: 0.6871 - val_loss: 0.5075 - val_accuracy: 0.6668
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 35/100
# 155/155 - 7s - loss: 0.4520 - accuracy: 0.6925 - val_loss: 0.5541 - val_accuracy: 0.6574
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 36/100
# 155/155 - 7s - loss: 0.4332 - accuracy: 0.7242 - val_loss: 0.6415 - val_accuracy: 0.6070
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 37/100
# 155/155 - 7s - loss: 0.4269 - accuracy: 0.7032 - val_loss: 0.4985 - val_accuracy: 0.7074
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 38/100
# 155/155 - 7s - loss: 0.4383 - accuracy: 0.6935 - val_loss: 0.5919 - val_accuracy: 0.5763
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 39/100
# 155/155 - 7s - loss: 0.4319 - accuracy: 0.7139 - val_loss: 0.4935 - val_accuracy: 0.7139
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 40/100
# 155/155 - 7s - loss: 0.3999 - accuracy: 0.7438 - val_loss: 0.4666 - val_accuracy: 0.7262
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 41/100
# 155/155 - 7s - loss: 0.3765 - accuracy: 0.7473 - val_loss: 0.3877 - val_accuracy: 0.7931
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 42/100
# 155/155 - 7s - loss: 0.4298 - accuracy: 0.7349 - val_loss: 0.4648 - val_accuracy: 0.7050
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 43/100
# 155/155 - 7s - loss: 0.4064 - accuracy: 0.7325 - val_loss: 0.4885 - val_accuracy: 0.7163
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 44/100
# 155/155 - 7s - loss: 0.3852 - accuracy: 0.7448 - val_loss: 0.4224 - val_accuracy: 0.7630
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 45/100
# 155/155 - 7s - loss: 0.3715 - accuracy: 0.7533 - val_loss: 0.5011 - val_accuracy: 0.7125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 46/100
# 155/155 - 7s - loss: 0.3772 - accuracy: 0.7669 - val_loss: 0.4579 - val_accuracy: 0.7375
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 47/100
# 155/155 - 7s - loss: 0.3691 - accuracy: 0.7451 - val_loss: 0.4071 - val_accuracy: 0.7672
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 48/100
# 155/155 - 7s - loss: 0.3355 - accuracy: 0.7931 - val_loss: 0.4401 - val_accuracy: 0.7630
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 49/100
# 155/155 - 7s - loss: 0.3733 - accuracy: 0.7434 - val_loss: 0.4714 - val_accuracy: 0.7361
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 50/100
# 155/155 - 7s - loss: 0.3621 - accuracy: 0.7659 - val_loss: 0.3947 - val_accuracy: 0.7969
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 51/100
# 155/155 - 7s - loss: 0.3462 - accuracy: 0.7879 - val_loss: 0.4725 - val_accuracy: 0.7639
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 52/100
# 155/155 - 7s - loss: 0.3768 - accuracy: 0.7489 - val_loss: 0.3952 - val_accuracy: 0.7724
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 53/100
# 155/155 - 7s - loss: 0.3652 - accuracy: 0.7519 - val_loss: 0.4691 - val_accuracy: 0.7375
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 54/100
# 155/155 - 7s - loss: 0.3379 - accuracy: 0.7828 - val_loss: 0.5864 - val_accuracy: 0.6833
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 55/100
# 155/155 - 7s - loss: 0.3694 - accuracy: 0.7725 - val_loss: 0.4506 - val_accuracy: 0.7686
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 56/100
# 155/155 - 7s - loss: 0.3132 - accuracy: 0.7984 - val_loss: 0.3893 - val_accuracy: 0.8162
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 57/100
# 155/155 - 7s - loss: 0.3241 - accuracy: 0.8152 - val_loss: 0.4673 - val_accuracy: 0.7677
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 58/100
# 155/155 - 7s - loss: 0.2964 - accuracy: 0.8170 - val_loss: 0.3972 - val_accuracy: 0.8058
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 59/100
# 155/155 - 7s - loss: 0.3121 - accuracy: 0.8099 - val_loss: 0.5213 - val_accuracy: 0.7380
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 60/100
# 155/155 - 7s - loss: 0.3481 - accuracy: 0.7911 - val_loss: 0.4380 - val_accuracy: 0.8058
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 61/100
# 155/155 - 7s - loss: 0.3060 - accuracy: 0.8204 - val_loss: 0.3979 - val_accuracy: 0.8270
# Restoring model weights from the end of the best epoch.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00061: early stopping
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# Best model:
# model                                  cnn
# accuracy                           0.93968
# f1-score                           0.59407
# Cohen kappa                       0.188183
# Confusion Matrix    [[1976, 67], [61, 18]]
# Name: 0, dtype: object
#      model  accuracy  f1-score  Cohen kappa         Confusion Matrix
# 0      cnn  0.939680  0.594070     0.188183   [[1976, 67], [61, 18]]
# 2      gru  0.814797  0.544207     0.139330  [[1682, 361], [32, 47]]
# 1  cnn-gru  0.794533  0.543207     0.150229  [[1630, 413], [23, 56]]
# 3     lstm  0.793120  0.519737     0.100575  [[1642, 401], [38, 41]]
# cp: cannot create directory '/content/drive/MyDrive/sequenceModelResults0': No such file or directory

# %%
model_df.style.background_gradient(cmap='coolwarm',axis=0)
# Out:
# <style  type="text/css" >
# #T_5050ec76_b973_11eb_a746_0242ac1c0002row0_col1,#T_5050ec76_b973_11eb_a746_0242ac1c0002row0_col2,#T_5050ec76_b973_11eb_a746_0242ac1c0002row0_col3{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_5050ec76_b973_11eb_a746_0242ac1c0002row1_col1{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_5050ec76_b973_11eb_a746_0242ac1c0002row1_col2{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_5050ec76_b973_11eb_a746_0242ac1c0002row1_col3{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_5050ec76_b973_11eb_a746_0242ac1c0002row2_col1{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_5050ec76_b973_11eb_a746_0242ac1c0002row2_col2{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_5050ec76_b973_11eb_a746_0242ac1c0002row2_col3{
#             background-color:  #edd2c3;
#             color:  #000000;
#         }#T_5050ec76_b973_11eb_a746_0242ac1c0002row3_col1,#T_5050ec76_b973_11eb_a746_0242ac1c0002row3_col2,#T_5050ec76_b973_11eb_a746_0242ac1c0002row3_col3{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_5050ec76_b973_11eb_a746_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model</th>        <th class="col_heading level0 col1" >accuracy</th>        <th class="col_heading level0 col2" >f1-score</th>        <th class="col_heading level0 col3" >Cohen kappa</th>        <th class="col_heading level0 col4" >Confusion Matrix</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5050ec76_b973_11eb_a746_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row0_col0" class="data row0 col0" >cnn</td>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row0_col1" class="data row0 col1" >0.939680</td>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row0_col2" class="data row0 col2" >0.594070</td>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row0_col3" class="data row0 col3" >0.188183</td>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row0_col4" class="data row0 col4" >[[1976   67]
#  [  61   18]]</td>
#             </tr>
#             <tr>
#                         <th id="T_5050ec76_b973_11eb_a746_0242ac1c0002level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row1_col0" class="data row1 col0" >gru</td>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row1_col1" class="data row1 col1" >0.814797</td>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row1_col2" class="data row1 col2" >0.544207</td>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row1_col3" class="data row1 col3" >0.139330</td>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row1_col4" class="data row1 col4" >[[1682  361]
#  [  32   47]]</td>
#             </tr>
#             <tr>
#                         <th id="T_5050ec76_b973_11eb_a746_0242ac1c0002level0_row2" class="row_heading level0 row2" >1</th>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row2_col0" class="data row2 col0" >cnn-gru</td>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row2_col1" class="data row2 col1" >0.794533</td>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row2_col2" class="data row2 col2" >0.543207</td>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row2_col3" class="data row2 col3" >0.150229</td>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row2_col4" class="data row2 col4" >[[1630  413]
#  [  23   56]]</td>
#             </tr>
#             <tr>
#                         <th id="T_5050ec76_b973_11eb_a746_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row3_col0" class="data row3 col0" >lstm</td>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row3_col1" class="data row3 col1" >0.793120</td>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row3_col2" class="data row3 col2" >0.519737</td>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row3_col3" class="data row3 col3" >0.100575</td>
#                         <td id="T_5050ec76_b973_11eb_a746_0242ac1c0002row3_col4" class="data row3 col4" >[[1642  401]
#  [  38   41]]</td>
#             </tr>
#     </tbody></table>

# %%
import seaborn as sns

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 23
plt.rcParams['figure.titlesize'] = 26
plt.rcParams['xtick.major.size'] = 10
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['ytick.major.size'] = 10
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.minor.size'] = 5
plt.rcParams['ytick.minor.width'] = 1
plt.rcParams['xtick.minor.size'] = 5
sns.set_style('ticks')

# %%
def normalized_confusion_matrix(y_test, conf_mat, model):
    _ , counts = np.unique(y_test,return_counts=True)
    conf_mat = (conf_mat.T/counts).T
    plt.figure(figsize=(6,5))
    ax=sns.heatmap(conf_mat,fmt='.2f',annot=True,annot_kws={'size':20},lw=2, cbar=True, cbar_kws={'label':'% Class accuracy'})
    plt.title(f'Confusion Matrix ({model})',size=22)
    plt.xticks(size=20)
    plt.yticks(size=20)
    ax.figure.axes[-1].yaxis.label.set_size(20) ##colorbar label
    cax = plt.gcf().axes[-1]  ##colorbar ticks
    cax.tick_params(labelsize=20) ## colorbar ticks
    plt.savefig(f'confusion-matrix-{model}.png',dpi=300)

# %%
i = 0
for score in model_scores:
  conf_mat = score[METRIC_CONFUSION_MATRIX]
  normalized_confusion_matrix(y_test,conf_mat, model_list[i])
  i = i + 1

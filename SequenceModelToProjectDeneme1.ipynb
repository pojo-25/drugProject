# %% [markdown]
# <a href="https://colab.research.google.com/github/pojo-25/drugProject/blob/branchProjectTrial0/SequenceModelToProjectDeneme1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, cohen_kappa_score, f1_score, confusion_matrix
import numpy as np

# %%
# data_path = '/content/data/HIV.csv'
# col_smiles = 'smiles'
# col_target = 'HIV_active'


# # read data
# df = pd.read_csv(data_path, sep=',')
# df_no_na = df[[col_smiles, col_target]].dropna()

# X = df_no_na[col_smiles]
# y = df_no_na[col_target].values

# print(X)

# %%
col_smiles = 'canonical_smiles'
col_target = 'bioactivity_class'

METRIC_ACCURACY = 'accuracy'
METRIC_F1_SCORE = 'f1-score'
METRIC_COHEN_KAPPA = 'Cohen kappa'
METRIC_CONFUSION_MATRIX = 'Confusion Matrix'


CLASSES = ['benign', 'malignant']
TEST_RATIO = 0.2
SEED = 0

data_path = '/content/data/abl_kinase-data.csv'

# %%
def read_data(data_path, col_smiles='smiles', col_target='HIV_active'):
    """Split original data into train data and test data.
    :param data_path: str, path to the a CSV data file
    :param col_smiles: str, name of smiles column
    :param col_target: str, name of target column
    :param test_ratio: float, proportion of the original data for testset, must be from 0 to 1
    :param seed: int, randomization seed for reproducibility
    :return (X, y)
    """
    

    # read data
    df = pd.read_csv(data_path, sep=',')
    df_no_na = df[[col_smiles, col_target]].dropna()

    X = df_no_na[col_smiles]
    y = df_no_na[col_target].values

    df['new_Bio'] = pd.factorize(df.bioactivity_class)[0]

    df.head()

    y = df['new_Bio'].values

    return X, y

                
def get_prediction_score(y_label, y_predict):
    """Evaluate predictions using different evaluation metrics.
    :param y_label: list, contains true label
    :param y_predict: list, contains predicted label
    :return scores: dict, evaluation metrics on the prediction
    """
    scores = {}
    scores[METRIC_ACCURACY] = accuracy_score(y_label, y_predict)
    scores[METRIC_F1_SCORE] = f1_score(y_label, y_predict, labels=None, average='macro', sample_weight=None)
    scores[METRIC_COHEN_KAPPA] = cohen_kappa_score(y_label, y_predict)
    scores[METRIC_CONFUSION_MATRIX] = confusion_matrix(y_label, y_predict)
    
    return scores

# %%
import os
import sys
sys.path.insert(0, os.getcwd()) # add current working directory to pythonpath



import tensorflow as tf

from tensorflow.python.keras import backend as K
#os.environ["CUDA_VISIBLE_DEVICES"]="0" # Use only the 1st GPU
tf_config = tf.compat.v1.ConfigProto()
sess = tf.compat.v1.Session(config=tf_config)
K.set_session(sess)


from tensorflow.keras import callbacks
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Flatten
from tensorflow.keras.layers import Embedding, LSTM, GlobalMaxPooling1D, SpatialDropout1D, Conv1D, MaxPooling1D, GRU, Bidirectional
from tensorflow.keras import optimizers
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight


import warnings
import gc

# %%
# import os
# import sys
# sys.path.insert(0, os.getcwd()) # add current working directory to pythonpath



# import keras.backend as K
# import numpy as np
# import tensorflow as tf
# from keras import callbacks
# from keras.optimizers import Adam
# from keras.models import load_model
# from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
# from keras.models import Sequential
# from keras.models import Model
# from keras.layers import Input, Dense, Dropout, BatchNormalization, Flatten
# from keras.layers import Embedding, LSTM, GlobalMaxPooling1D, SpatialDropout1D, Conv1D, MaxPooling1D, GRU, Bidirectional
# from keras import optimizers
# from sklearn.model_selection import train_test_split
# from sklearn.utils import class_weight

# import warnings
# import argparse
# import gc

# %%
def generate_tokens(smiles, len_percentile=100):
    """
    Generate character tokens from smiles
    :param smiles: Pandas series, containing smiles
    :param len_percentile: percentile of smiles length to set as max length
    :return tokens
    :return num_words
    :return max_phrase_len
    """ 
    
    # Get max length of smiles
    smiles_len = smiles.apply(lambda p: len(p))
    max_phrase_len = int(np.percentile(smiles_len, len_percentile))
    print('True max length is ' + str(np.max(smiles_len)) + ', ' + str(max_phrase_len) + ' is set the length cutoff.')
        
    # Get unique words
    unique_words = np.unique(np.concatenate(smiles.apply(lambda p: np.array(list(p))).values, axis=0))
    num_words = len(unique_words)
    print('Vocab size is ' + str(num_words))
    
    tokenizer = Tokenizer(
        num_words = num_words,
        filters = '$',
        char_level = True,
        oov_token = '_'
    )

    #print(num_words)
    
    tokenizer.fit_on_texts(smiles)
    sequences = tokenizer.texts_to_sequences(smiles)
    tokens = pad_sequences(sequences, maxlen = max_phrase_len, padding='post', truncating='post')
    
    return tokens, num_words, max_phrase_len

# %%
smiles, y = read_data(data_path, col_smiles='canonical_smiles', col_target='bioactivity_class')
tokens, num_words, max_phrase_len = generate_tokens(smiles, len_percentile=100)
# Out:
# True max length is 254, 254 is set the length cutoff.
# Vocab size is 35

# %%
def create_model(model_type, num_words, input_length, output_dim=1, dropout_rate=0.0):
    """Build different sequence model
    :param model_type: str, can be 'cnn-gru', 'cnn', 'gru', 'lstm'
    :param num_words: int
    :param input_length: int
    :param output_dim: int
    :return model: Keras model
    """ 
    
    model = Sequential()
    if model_type == 'lstm': # LSTM - LSTM
        model.add(Embedding(num_words+1, 50, input_length=input_length))
        model.add(Bidirectional(LSTM(128, return_sequences=True)))
        model.add(Bidirectional(LSTM(128)))
        model.add(Dense(128, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(output_dim, activation='sigmoid'))
    elif model_type == 'gru': # GRU - GRU
        model.add(Embedding(num_words+1, 50, input_length=input_length))
        model.add(Bidirectional(GRU(128, return_sequences=True)))
        model.add(Bidirectional(GRU(128)))
        model.add(Dense(128, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(output_dim, activation='sigmoid'))
    elif model_type == 'cnn-gru': # 1D CNN - GRU
        model.add(Embedding(num_words+1, 50, input_length=input_length))
        model.add(Conv1D(192,3,activation='relu'))
        model.add(Bidirectional(GRU(224, return_sequences=True)))
        model.add(Bidirectional(GRU(384)))
        model.add(Dense(128, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(output_dim, activation='sigmoid'))
    elif model_type == 'cnn': # 1D CNN
        model.add(Embedding(num_words+1, 50, input_length=input_length))
        model.add(Conv1D(192, 10, activation='relu'))
        model.add(BatchNormalization())
        model.add(Conv1D(192, 3, activation='relu'))
        model.add(Flatten())
        model.add(Dense(128, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(output_dim, activation='sigmoid'))
    # elif model_type == 'cnn-lstm': # 1D CNN - LSTM
    #     model.add(Embedding(num_words+1, 50, input_length=input_length))
    #     model.add(Conv1D(192,3,activation='relu'))
    #     model.add(Bidirectional(LSTM(224, return_sequences=True)))
    #     model.add(Bidirectional(LSTM(384)))
    #     model.add(Dense(128, activation='relu'))
    #     model.add(Dropout(dropout_rate))
    #     model.add(Dense(output_dim, activation='sigmoid'))
    else:
        #raise ValueError(model_type + ' is not supported.')
        print('wrong model')
 
    model.summary()    
    return model

# %%
# def build_sequence_model(trainset, testset, model_type, num_words, input_length, output_dim=1, dropout_rate=0.0,
#                      batch_size=32, nb_epochs=100, lr=0.001):
#     """Train and evaluate CNN model
#     :param trainset: (X_train, y_train)
#     :param testset: (X_test, y_test)
#     :param model_type: str, can be 'cnn-gru', 'cnn', 'gru', 'lstm'
#     :param num_words: int
#     :param input_length: int
#     :param output_dim: int
#     :param batch_size: int, batch size for model training
#     :param nb_epochs: int, number of training epoches
#     :param lr: float, learning rate
#     :param save_path: path to save model
#     :return model: fitted Keras model
#     :return scores: dict, scores on test set for the fitted Keras model
#     """
    
#     # Create model
#     model = create_model(model_type=model_type, num_words=num_words, input_length=input_length, output_dim=output_dim,
#                          dropout_rate=dropout_rate)
    
#     # Callback list
#     callback_list = []
#     # monitor val_loss and terminate training if no improvement
#     early_stop = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.00001, \
#                 patience=20, verbose=2, mode='auto', restore_best_weights=True)
#     callback_list.append(early_stop)
    
#     # if save_path is not None:
#     #     # save best model based on val_acc during training
#     #     checkpoint = callbacks.ModelCheckpoint(os.path.join(save_path, '.h5'), monitor='val_acc', \
#     #                 verbose=0, save_best_only=True, save_weights_only=False, mode='auto')
#     #     callback_list.append(checkpoint)
        
#     # Get train and test set
#     (X_train, y_train) = trainset
#     (X_test, y_test) = testset
    
#     # Compute class weights
#     weight_list = class_weight.compute_class_weight('balanced', np.unique(y_train), y_train)
#     weight_dict = {}
#     for i in range(len(np.unique(y_train))):
#         weight_dict[np.unique(y_train)[i]] = weight_list[i]
    
#     # Train only classification head
#     optimizer = Adam(lr=lr, decay=1e-6, momentum=0.9, nesterov=True)
#     model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
#     model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=nb_epochs, \
#                         class_weight=weight_dict, callbacks=callback_list, verbose=2)
    
#     # Evaluate model    
#     prediction = model.predict(X_test)
#     y_val_predict = (prediction > 0.5).astype('uint8')
#     with warnings.catch_warnings():
#         warnings.simplefilter('ignore')  # disable the warning on f1-score with not all labels
#         scores = get_prediction_score(y_val, y_val_predict)
        
#     return model, scores

# %%
import matplotlib.pyplot as plt

# %%
def build_sequence_model(trainset, testset, model_type, num_words, input_length, output_dim=1, dropout_rate=0.0,
                     batch_size=32, nb_epochs=100, lr=0.001,
                     save_path=None):
    """Train and evaluate CNN model
    :param trainset: (X_train, y_train)
    :param testset: (X_test, y_test)
    :param model_type: str, can be 'cnn-gru', 'cnn', 'gru', 'lstm'
    :param num_words: int
    :param input_length: int
    :param output_dim: int
    :param batch_size: int, batch size for model training
    :param nb_epochs: int, number of training epoches
    :param lr: float, learning rate
    :param save_path: path to save model
    :return model: fitted Keras model
    :return scores: dict, scores on test set for the fitted Keras model
    """
    
    # Create model
    model = create_model(model_type=model_type, num_words=num_words, input_length=input_length, output_dim=output_dim,
                         dropout_rate=dropout_rate)
    
    # Callback list
    callback_list = []
    # monitor val_loss and terminate training if no improvement
    early_stop = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.00001, \
                patience=20, verbose=2, mode='auto', restore_best_weights=True)
    callback_list.append(early_stop)
    
    if save_path is not None:
        # save best model based on val_acc during training
        checkpoint = callbacks.ModelCheckpoint(os.path.join(save_path, model_type + '.h5'), monitor='val_acc', \
                    verbose=0, save_best_only=True, save_weights_only=False, mode='auto')
        callback_list.append(checkpoint)
        
    # Get train and test set
    (X_train, y_train) = trainset
    (X_test, y_test) = testset
    
    # Compute class weights
    weight_list = class_weight.compute_class_weight('balanced', np.unique(y_train), y_train)
    weight_dict = {}
    for i in range(len(np.unique(y_train))):
        weight_dict[np.unique(y_train)[i]] = weight_list[i]
    
    # Train only classification head
    optimizer = Adam(lr=lr, decay=1e-6)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=nb_epochs, \
                        class_weight=weight_dict, callbacks=callback_list, verbose=2)
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

        
    # Evaluate model    
    prediction = model.predict(X_test)
    y_val_predict = (prediction > 0.5).astype('uint8')
    y_val = y_test
    with warnings.catch_warnings():
        warnings.filterwarnings('ignore')  # disable the warning on f1-score with not all labels
        scores = get_prediction_score(y_val, y_val_predict)
        
    return model, scores

# %%
data_path = '/content/data/abl_kinase-data.csv'


model_list = ['cnn', 'cnn-gru', 'gru', 'lstm']
batch_size = 16
nb_epochs = 100
lr = 0.001
save_path = '/content/data'

WORK_DIRECTORY = '/content/data'

# Make save_path
# if save_path is not None:
#     os.makedirs(os.path.join(save_path, 'sequence_models'), exist_ok=True)

# Read data
smiles, y = read_data(data_path, col_smiles='canonical_smiles', col_target='bioactivity_class')
tokens, num_words, max_phrase_len = generate_tokens(smiles, len_percentile=100)

# Get train and test set
X_train, X_test, y_train, y_test = train_test_split(tokens, y, test_size=TEST_RATIO, shuffle=True, stratify=y,
                                                  random_state=SEED)

# Build en evaluate graph models
model_scores = []
for model_type in model_list:
    model, scores = build_sequence_model((X_train, y_train), (X_test, y_test), model_type, num_words, max_phrase_len,
                                          output_dim=1, dropout_rate=0.0,
                                          batch_size=batch_size, nb_epochs=nb_epochs, lr=lr,
                             save_path=os.path.join(save_path, 'sequence_models', model_type + '.h5'))
    model_scores.append(scores)
        
    # force release memory
    K.clear_session()
    del model
    gc.collect()

model_df = pd.DataFrame({'model': model_list,

                    METRIC_ACCURACY: [score[METRIC_ACCURACY] for score in model_scores],
                    METRIC_F1_SCORE: [score[METRIC_F1_SCORE] for score in model_scores],
                    METRIC_COHEN_KAPPA: [score[METRIC_COHEN_KAPPA] for score in model_scores],
                    METRIC_CONFUSION_MATRIX: [score[METRIC_CONFUSION_MATRIX] for score in model_scores]                            
                      })
model_df = model_df[['model', METRIC_ACCURACY, METRIC_F1_SCORE, METRIC_COHEN_KAPPA,
                      METRIC_CONFUSION_MATRIX]]


model_df.to_csv(os.path.join(WORK_DIRECTORY, 'summary_sequence_model.csv'), index=False)
model_df.sort_values(by=[METRIC_ACCURACY, METRIC_F1_SCORE, METRIC_COHEN_KAPPA],
                      ascending=False, inplace=True)
print('Best model:\n' + str(model_df.iloc[0]))

print(model_df)



# !cp -r /content/data /content/drive/MyDrive/sequenceModelResults0
# Out:
# True max length is 254, 254 is set the length cutoff.
# Vocab size is 35
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 254, 50)           1800
# _________________________________________________________________
# conv1d (Conv1D)              (None, 245, 192)          96192
# _________________________________________________________________
# batch_normalization (BatchNo (None, 245, 192)          768
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 243, 192)          110784
# _________________________________________________________________
# flatten (Flatten)            (None, 46656)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5972096
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 6,181,769
# Trainable params: 6,181,385
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 54/54 - 34s - loss: 0.7209 - accuracy: 0.6642 - val_loss: 0.7044 - val_accuracy: 0.2662
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 54/54 - 1s - loss: 0.3665 - accuracy: 0.7892 - val_loss: 0.6540 - val_accuracy: 0.7269
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 54/54 - 1s - loss: 0.2610 - accuracy: 0.8657 - val_loss: 0.6171 - val_accuracy: 0.7593
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 54/54 - 1s - loss: 0.1930 - accuracy: 0.9114 - val_loss: 0.7889 - val_accuracy: 0.2963
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 54/54 - 1s - loss: 0.1855 - accuracy: 0.9172 - val_loss: 0.4558 - val_accuracy: 0.8403
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 54/54 - 1s - loss: 0.1188 - accuracy: 0.9456 - val_loss: 0.3864 - val_accuracy: 0.8449
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 54/54 - 1s - loss: 0.0962 - accuracy: 0.9635 - val_loss: 0.3406 - val_accuracy: 0.8727
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 54/54 - 1s - loss: 0.1062 - accuracy: 0.9572 - val_loss: 0.3131 - val_accuracy: 0.8611
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 54/54 - 1s - loss: 0.0664 - accuracy: 0.9745 - val_loss: 0.3025 - val_accuracy: 0.8704
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 54/54 - 1s - loss: 0.0751 - accuracy: 0.9589 - val_loss: 0.2893 - val_accuracy: 0.8657
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 54/54 - 1s - loss: 0.0570 - accuracy: 0.9682 - val_loss: 0.3155 - val_accuracy: 0.8611
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 54/54 - 1s - loss: 0.0461 - accuracy: 0.9693 - val_loss: 0.3628 - val_accuracy: 0.8634
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 54/54 - 1s - loss: 0.0390 - accuracy: 0.9710 - val_loss: 0.4151 - val_accuracy: 0.8657
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 54/54 - 1s - loss: 0.0364 - accuracy: 0.9728 - val_loss: 0.5153 - val_accuracy: 0.8657
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 54/54 - 1s - loss: 0.0405 - accuracy: 0.9792 - val_loss: 0.4426 - val_accuracy: 0.8681
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 54/54 - 1s - loss: 0.0385 - accuracy: 0.9716 - val_loss: 0.5117 - val_accuracy: 0.8495
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 54/54 - 1s - loss: 0.0315 - accuracy: 0.9728 - val_loss: 0.5416 - val_accuracy: 0.8634
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 54/54 - 1s - loss: 0.0337 - accuracy: 0.9739 - val_loss: 0.6228 - val_accuracy: 0.8588
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 54/54 - 1s - loss: 0.0294 - accuracy: 0.9745 - val_loss: 0.5813 - val_accuracy: 0.8634
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 54/54 - 1s - loss: 0.0344 - accuracy: 0.9757 - val_loss: 0.5850 - val_accuracy: 0.8634
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 54/54 - 1s - loss: 0.0320 - accuracy: 0.9745 - val_loss: 0.6002 - val_accuracy: 0.8657
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 54/54 - 1s - loss: 0.0264 - accuracy: 0.9751 - val_loss: 0.6336 - val_accuracy: 0.8542
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 54/54 - 1s - loss: 0.0250 - accuracy: 0.9751 - val_loss: 0.6648 - val_accuracy: 0.8519
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# 54/54 - 1s - loss: 0.0248 - accuracy: 0.9751 - val_loss: 0.6973 - val_accuracy: 0.8611
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# 54/54 - 1s - loss: 0.0271 - accuracy: 0.9751 - val_loss: 0.7315 - val_accuracy: 0.8681
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# 54/54 - 1s - loss: 0.0463 - accuracy: 0.9768 - val_loss: 0.5528 - val_accuracy: 0.8542
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/100
# 54/54 - 1s - loss: 0.0299 - accuracy: 0.9763 - val_loss: 0.7034 - val_accuracy: 0.8681
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/100
# 54/54 - 1s - loss: 0.0352 - accuracy: 0.9728 - val_loss: 0.5606 - val_accuracy: 0.8634
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/100
# 54/54 - 1s - loss: 0.0296 - accuracy: 0.9734 - val_loss: 0.6664 - val_accuracy: 0.8542
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/100
# 54/54 - 1s - loss: 0.0365 - accuracy: 0.9739 - val_loss: 0.7494 - val_accuracy: 0.8611
# Restoring model weights from the end of the best epoch.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00030: early stopping
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 254, 50)           1800
# _________________________________________________________________
# conv1d (Conv1D)              (None, 252, 192)          28992
# _________________________________________________________________
# bidirectional (Bidirectional (None, 252, 448)          561792
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 768)               1921536
# _________________________________________________________________
# dense (Dense)                (None, 128)               98432
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,612,681
# Trainable params: 2,612,681
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 54/54 - 10s - loss: 0.6921 - accuracy: 0.5113 - val_loss: 0.6008 - val_accuracy: 0.7407
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 54/54 - 4s - loss: 0.6472 - accuracy: 0.6566 - val_loss: 0.6611 - val_accuracy: 0.7454
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 54/54 - 5s - loss: 0.6068 - accuracy: 0.7417 - val_loss: 0.6208 - val_accuracy: 0.6944
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 54/54 - 5s - loss: 0.5893 - accuracy: 0.7093 - val_loss: 0.7212 - val_accuracy: 0.4514
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 54/54 - 5s - loss: 0.5534 - accuracy: 0.6294 - val_loss: 0.5093 - val_accuracy: 0.6921
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 54/54 - 5s - loss: 0.5317 - accuracy: 0.6630 - val_loss: 0.5235 - val_accuracy: 0.7431
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 54/54 - 5s - loss: 0.4957 - accuracy: 0.7070 - val_loss: 0.5663 - val_accuracy: 0.7060
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 54/54 - 5s - loss: 0.5090 - accuracy: 0.6850 - val_loss: 0.4524 - val_accuracy: 0.7755
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 54/54 - 5s - loss: 0.4454 - accuracy: 0.7690 - val_loss: 0.3864 - val_accuracy: 0.8171
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 54/54 - 5s - loss: 0.4314 - accuracy: 0.7655 - val_loss: 0.4007 - val_accuracy: 0.8148
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 54/54 - 5s - loss: 0.3822 - accuracy: 0.7962 - val_loss: 0.4576 - val_accuracy: 0.7778
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 54/54 - 5s - loss: 0.4119 - accuracy: 0.8049 - val_loss: 0.4862 - val_accuracy: 0.7685
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 54/54 - 5s - loss: 0.3634 - accuracy: 0.8188 - val_loss: 0.4496 - val_accuracy: 0.7986
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 54/54 - 5s - loss: 0.3451 - accuracy: 0.8350 - val_loss: 0.4286 - val_accuracy: 0.8310
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 54/54 - 5s - loss: 0.4533 - accuracy: 0.7898 - val_loss: 0.4755 - val_accuracy: 0.7685
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 54/54 - 5s - loss: 0.5182 - accuracy: 0.7499 - val_loss: 0.7434 - val_accuracy: 0.5903
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 54/54 - 5s - loss: 0.7509 - accuracy: 0.5565 - val_loss: 0.7519 - val_accuracy: 0.4722
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 54/54 - 5s - loss: 0.6625 - accuracy: 0.5883 - val_loss: 0.5058 - val_accuracy: 0.8171
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 54/54 - 5s - loss: 0.6525 - accuracy: 0.5964 - val_loss: 0.5306 - val_accuracy: 0.8171
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 54/54 - 5s - loss: 0.6544 - accuracy: 0.6450 - val_loss: 0.6469 - val_accuracy: 0.6181
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 54/54 - 5s - loss: 0.6051 - accuracy: 0.6688 - val_loss: 0.5698 - val_accuracy: 0.7546
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 54/54 - 5s - loss: 0.5561 - accuracy: 0.7122 - val_loss: 0.4912 - val_accuracy: 0.7176
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 54/54 - 5s - loss: 0.4638 - accuracy: 0.7528 - val_loss: 0.5190 - val_accuracy: 0.7292
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# 54/54 - 5s - loss: 0.4151 - accuracy: 0.7620 - val_loss: 0.5132 - val_accuracy: 0.7106
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# 54/54 - 5s - loss: 0.4298 - accuracy: 0.7539 - val_loss: 0.4982 - val_accuracy: 0.7315
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# 54/54 - 5s - loss: 0.3655 - accuracy: 0.8014 - val_loss: 0.5571 - val_accuracy: 0.7245
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/100
# 54/54 - 5s - loss: 0.3948 - accuracy: 0.8101 - val_loss: 0.4285 - val_accuracy: 0.7963
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/100
# 54/54 - 5s - loss: 0.3468 - accuracy: 0.8228 - val_loss: 0.4201 - val_accuracy: 0.7593
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/100
# 54/54 - 5s - loss: 0.3117 - accuracy: 0.8361 - val_loss: 0.4887 - val_accuracy: 0.8009
# Restoring model weights from the end of the best epoch.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00029: early stopping
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 254, 50)           1800
# _________________________________________________________________
# bidirectional (Bidirectional (None, 254, 256)          138240
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               296448
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 469,513
# Trainable params: 469,513
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 54/54 - 8s - loss: 0.6862 - accuracy: 0.4829 - val_loss: 0.6061 - val_accuracy: 0.4792
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 54/54 - 2s - loss: 0.6655 - accuracy: 0.5437 - val_loss: 0.6891 - val_accuracy: 0.4491
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 54/54 - 2s - loss: 0.6407 - accuracy: 0.5825 - val_loss: 0.6038 - val_accuracy: 0.5046
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 54/54 - 2s - loss: 0.6299 - accuracy: 0.6358 - val_loss: 0.6520 - val_accuracy: 0.6620
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 54/54 - 2s - loss: 0.7181 - accuracy: 0.5808 - val_loss: 0.6145 - val_accuracy: 0.8125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 54/54 - 2s - loss: 0.7167 - accuracy: 0.4997 - val_loss: 0.8367 - val_accuracy: 0.1875
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 54/54 - 2s - loss: 0.7082 - accuracy: 0.5524 - val_loss: 0.7302 - val_accuracy: 0.4653
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 54/54 - 2s - loss: 0.6816 - accuracy: 0.5101 - val_loss: 0.7103 - val_accuracy: 0.4653
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 54/54 - 2s - loss: 0.6784 - accuracy: 0.4870 - val_loss: 0.5727 - val_accuracy: 0.7616
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 54/54 - 2s - loss: 0.6905 - accuracy: 0.5761 - val_loss: 0.5208 - val_accuracy: 0.8125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 54/54 - 2s - loss: 0.6778 - accuracy: 0.5437 - val_loss: 0.7399 - val_accuracy: 0.3958
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 54/54 - 2s - loss: 0.6604 - accuracy: 0.5605 - val_loss: 0.6453 - val_accuracy: 0.6551
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 54/54 - 2s - loss: 0.6297 - accuracy: 0.6526 - val_loss: 0.5993 - val_accuracy: 0.7454
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 54/54 - 2s - loss: 0.6003 - accuracy: 0.6740 - val_loss: 0.6032 - val_accuracy: 0.7060
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 54/54 - 2s - loss: 0.5197 - accuracy: 0.7487 - val_loss: 0.6026 - val_accuracy: 0.7106
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 54/54 - 2s - loss: 0.4454 - accuracy: 0.7614 - val_loss: 0.7690 - val_accuracy: 0.6921
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 54/54 - 2s - loss: 0.4154 - accuracy: 0.7562 - val_loss: 0.5023 - val_accuracy: 0.7153
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 54/54 - 2s - loss: 0.3824 - accuracy: 0.7464 - val_loss: 0.4683 - val_accuracy: 0.7222
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 54/54 - 2s - loss: 0.3539 - accuracy: 0.7788 - val_loss: 0.4867 - val_accuracy: 0.7315
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 54/54 - 2s - loss: 0.3506 - accuracy: 0.7846 - val_loss: 0.4537 - val_accuracy: 0.7523
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 54/54 - 2s - loss: 0.3246 - accuracy: 0.8147 - val_loss: 0.3645 - val_accuracy: 0.8356
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 54/54 - 2s - loss: 0.3069 - accuracy: 0.8413 - val_loss: 0.3612 - val_accuracy: 0.8310
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 54/54 - 2s - loss: 0.2990 - accuracy: 0.8350 - val_loss: 0.3880 - val_accuracy: 0.8148
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# 54/54 - 2s - loss: 0.2772 - accuracy: 0.8564 - val_loss: 0.3814 - val_accuracy: 0.8287
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# 54/54 - 2s - loss: 0.4420 - accuracy: 0.7684 - val_loss: 0.6676 - val_accuracy: 0.6458
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# 54/54 - 2s - loss: 0.4772 - accuracy: 0.7348 - val_loss: 0.4065 - val_accuracy: 0.7847
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/100
# 54/54 - 2s - loss: 0.4709 - accuracy: 0.7585 - val_loss: 0.5796 - val_accuracy: 0.6759
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/100
# 54/54 - 2s - loss: 0.4008 - accuracy: 0.7979 - val_loss: 0.3564 - val_accuracy: 0.8310
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/100
# 54/54 - 2s - loss: 0.3559 - accuracy: 0.8292 - val_loss: 0.5256 - val_accuracy: 0.7292
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/100
# 54/54 - 2s - loss: 0.6040 - accuracy: 0.6584 - val_loss: 0.6414 - val_accuracy: 0.6713
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 31/100
# 54/54 - 2s - loss: 0.6044 - accuracy: 0.6317 - val_loss: 0.6083 - val_accuracy: 0.6944
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 32/100
# 54/54 - 2s - loss: 0.5461 - accuracy: 0.6885 - val_loss: 0.5401 - val_accuracy: 0.6644
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 33/100
# 54/54 - 2s - loss: 0.5316 - accuracy: 0.6920 - val_loss: 0.7205 - val_accuracy: 0.5671
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 34/100
# 54/54 - 2s - loss: 0.4721 - accuracy: 0.7267 - val_loss: 0.5403 - val_accuracy: 0.6806
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 35/100
# 54/54 - 2s - loss: 0.4446 - accuracy: 0.7423 - val_loss: 0.4905 - val_accuracy: 0.7361
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 36/100
# 54/54 - 2s - loss: 0.4013 - accuracy: 0.7829 - val_loss: 0.6150 - val_accuracy: 0.7176
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 37/100
# 54/54 - 2s - loss: 0.4023 - accuracy: 0.7811 - val_loss: 0.5575 - val_accuracy: 0.7384
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 38/100
# 54/54 - 2s - loss: 0.3946 - accuracy: 0.8002 - val_loss: 0.4999 - val_accuracy: 0.7454
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 39/100
# 54/54 - 2s - loss: 0.3767 - accuracy: 0.7869 - val_loss: 0.5626 - val_accuracy: 0.7384
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 40/100
# 54/54 - 2s - loss: 0.3370 - accuracy: 0.8298 - val_loss: 0.5410 - val_accuracy: 0.7546
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 41/100
# 54/54 - 2s - loss: 0.3429 - accuracy: 0.8188 - val_loss: 0.5692 - val_accuracy: 0.7477
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 42/100
# 54/54 - 2s - loss: 0.3153 - accuracy: 0.8500 - val_loss: 0.6495 - val_accuracy: 0.7292
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 43/100
# 54/54 - 2s - loss: 0.3486 - accuracy: 0.8205 - val_loss: 0.4102 - val_accuracy: 0.8056
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 44/100
# 54/54 - 2s - loss: 0.3042 - accuracy: 0.8402 - val_loss: 0.4565 - val_accuracy: 0.7801
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 45/100
# 54/54 - 2s - loss: 0.3089 - accuracy: 0.8356 - val_loss: 0.4171 - val_accuracy: 0.7824
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 46/100
# 54/54 - 2s - loss: 0.2749 - accuracy: 0.8558 - val_loss: 0.4551 - val_accuracy: 0.7894
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 47/100
# 54/54 - 2s - loss: 0.2758 - accuracy: 0.8535 - val_loss: 0.4339 - val_accuracy: 0.7894
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 48/100
# 54/54 - 2s - loss: 0.2521 - accuracy: 0.8709 - val_loss: 0.4308 - val_accuracy: 0.7986
# Restoring model weights from the end of the best epoch.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00048: early stopping
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 254, 50)           1800
# _________________________________________________________________
# bidirectional (Bidirectional (None, 254, 256)          183296
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               394240
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 612,361
# Trainable params: 612,361
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 54/54 - 8s - loss: 0.6904 - accuracy: 0.5153 - val_loss: 0.5887 - val_accuracy: 0.7569
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 54/54 - 3s - loss: 0.5433 - accuracy: 0.7099 - val_loss: 0.5047 - val_accuracy: 0.6991
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 54/54 - 3s - loss: 0.5218 - accuracy: 0.7331 - val_loss: 0.4982 - val_accuracy: 0.6968
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 54/54 - 3s - loss: 0.6622 - accuracy: 0.6526 - val_loss: 0.7585 - val_accuracy: 0.1852
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 54/54 - 3s - loss: 0.6257 - accuracy: 0.6161 - val_loss: 0.7809 - val_accuracy: 0.7269
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 54/54 - 3s - loss: 0.6280 - accuracy: 0.6149 - val_loss: 0.8238 - val_accuracy: 0.3866
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 54/54 - 3s - loss: 0.6389 - accuracy: 0.4540 - val_loss: 0.6262 - val_accuracy: 0.4444
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 54/54 - 3s - loss: 0.7143 - accuracy: 0.5067 - val_loss: 0.5400 - val_accuracy: 0.8125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 54/54 - 3s - loss: 0.7018 - accuracy: 0.6063 - val_loss: 0.6988 - val_accuracy: 0.1875
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 54/54 - 3s - loss: 0.6942 - accuracy: 0.5547 - val_loss: 0.7541 - val_accuracy: 0.1875
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 54/54 - 3s - loss: 0.6950 - accuracy: 0.5744 - val_loss: 0.7206 - val_accuracy: 0.1875
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 54/54 - 3s - loss: 0.6938 - accuracy: 0.5345 - val_loss: 0.6733 - val_accuracy: 0.8125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 54/54 - 3s - loss: 0.6946 - accuracy: 0.5350 - val_loss: 0.7076 - val_accuracy: 0.1875
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 54/54 - 3s - loss: 0.6942 - accuracy: 0.2999 - val_loss: 0.6928 - val_accuracy: 0.4653
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 54/54 - 3s - loss: 0.6947 - accuracy: 0.5055 - val_loss: 0.6682 - val_accuracy: 0.8125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 54/54 - 3s - loss: 0.6945 - accuracy: 0.5530 - val_loss: 0.6802 - val_accuracy: 0.8125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 54/54 - 3s - loss: 0.6945 - accuracy: 0.3885 - val_loss: 0.6562 - val_accuracy: 0.8125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 54/54 - 3s - loss: 0.6940 - accuracy: 0.4864 - val_loss: 0.7066 - val_accuracy: 0.1875
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 54/54 - 3s - loss: 0.6951 - accuracy: 0.4760 - val_loss: 0.6982 - val_accuracy: 0.1875
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 54/54 - 3s - loss: 0.6937 - accuracy: 0.6039 - val_loss: 0.6994 - val_accuracy: 0.1875
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 54/54 - 3s - loss: 0.6942 - accuracy: 0.3949 - val_loss: 0.6642 - val_accuracy: 0.8125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 54/54 - 3s - loss: 0.6938 - accuracy: 0.5981 - val_loss: 0.6951 - val_accuracy: 0.4190
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 54/54 - 3s - loss: 0.6932 - accuracy: 0.1922 - val_loss: 0.6950 - val_accuracy: 0.4259
# Restoring model weights from the end of the best epoch.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00023: early stopping
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# Best model:
# model                                 cnn
# accuracy                         0.865741
# f1-score                         0.799744
# Cohen kappa                      0.601032
# Confusion Matrix    [[63, 18], [40, 311]]
# Name: 0, dtype: object
#      model  accuracy  f1-score  Cohen kappa       Confusion Matrix
# 0      cnn  0.865741  0.799744     0.601032  [[63, 18], [40, 311]]
# 2      gru  0.831019  0.764978     0.535771  [[65, 16], [57, 294]]
# 1  cnn-gru  0.817130  0.738393     0.481117  [[58, 23], [56, 295]]
# 3     lstm  0.696759  0.654554     0.364078  [[75, 6], [125, 226]]

# %%
model_df.style.background_gradient(cmap='coolwarm',axis=0)
# Out:
# <style  type="text/css" >
# #T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row0_col1,#T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row0_col2,#T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row0_col3{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row1_col1{
#             background-color:  #ee8669;
#             color:  #000000;
#         }#T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row1_col2{
#             background-color:  #f39577;
#             color:  #000000;
#         }#T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row1_col3{
#             background-color:  #f6a385;
#             color:  #000000;
#         }#T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row2_col1{
#             background-color:  #f7a889;
#             color:  #000000;
#         }#T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row2_col2{
#             background-color:  #eed0c0;
#             color:  #000000;
#         }#T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row2_col3{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row3_col1,#T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row3_col2,#T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row3_col3{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model</th>        <th class="col_heading level0 col1" >accuracy</th>        <th class="col_heading level0 col2" >f1-score</th>        <th class="col_heading level0 col3" >Cohen kappa</th>        <th class="col_heading level0 col4" >Confusion Matrix</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row0_col0" class="data row0 col0" >cnn</td>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row0_col1" class="data row0 col1" >0.865741</td>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row0_col2" class="data row0 col2" >0.799744</td>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row0_col3" class="data row0 col3" >0.601032</td>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row0_col4" class="data row0 col4" >[[ 63  18]
#  [ 40 311]]</td>
#             </tr>
#             <tr>
#                         <th id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row1_col0" class="data row1 col0" >gru</td>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row1_col1" class="data row1 col1" >0.831019</td>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row1_col2" class="data row1 col2" >0.764978</td>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row1_col3" class="data row1 col3" >0.535771</td>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row1_col4" class="data row1 col4" >[[ 65  16]
#  [ 57 294]]</td>
#             </tr>
#             <tr>
#                         <th id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002level0_row2" class="row_heading level0 row2" >1</th>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row2_col0" class="data row2 col0" >cnn-gru</td>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row2_col1" class="data row2 col1" >0.817130</td>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row2_col2" class="data row2 col2" >0.738393</td>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row2_col3" class="data row2 col3" >0.481117</td>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row2_col4" class="data row2 col4" >[[ 58  23]
#  [ 56 295]]</td>
#             </tr>
#             <tr>
#                         <th id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row3_col0" class="data row3 col0" >lstm</td>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row3_col1" class="data row3 col1" >0.696759</td>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row3_col2" class="data row3 col2" >0.654554</td>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row3_col3" class="data row3 col3" >0.364078</td>
#                         <td id="T_ae9e3f62_b816_11eb_bf70_0242ac1c0002row3_col4" class="data row3 col4" >[[ 75   6]
#  [125 226]]</td>
#             </tr>
#     </tbody></table>

# %%
import seaborn as sns

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 23
plt.rcParams['figure.titlesize'] = 26
plt.rcParams['xtick.major.size'] = 10
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['ytick.major.size'] = 10
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.minor.size'] = 5
plt.rcParams['ytick.minor.width'] = 1
plt.rcParams['xtick.minor.size'] = 5
sns.set_style('ticks')

# %%
def normalized_confusion_matrix(y_test, conf_mat, model):
    _ , counts = np.unique(y_test,return_counts=True)
    conf_mat = (conf_mat.T/counts).T
    plt.figure(figsize=(6,5))
    ax=sns.heatmap(conf_mat,fmt='.2f',annot=True,annot_kws={'size':20},lw=2, cbar=True, cbar_kws={'label':'% Class accuracy'})
    plt.title(f'Confusion Matrix ({model})',size=22)
    plt.xticks(size=20)
    plt.yticks(size=20)
    ax.figure.axes[-1].yaxis.label.set_size(20) ##colorbar label
    cax = plt.gcf().axes[-1]  ##colorbar ticks
    cax.tick_params(labelsize=20) ## colorbar ticks
    plt.savefig(f'confusion-matrix-{model}.png',dpi=300)

# %%
i = 0
for score in model_scores:
  conf_mat = score[METRIC_CONFUSION_MATRIX]
  normalized_confusion_matrix(y_test,conf_mat, model_list[i])
  i = i + 1

# %% [markdown]
# <a href="https://colab.research.google.com/github/pojo-25/drugProject/blob/branchProjectTrial0/SequenceModelToProjectDeneme0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, cohen_kappa_score, f1_score, confusion_matrix
import numpy as np

# %%
# data_path = '/content/data/HIV.csv'
# col_smiles = 'smiles'
# col_target = 'HIV_active'


# # read data
# df = pd.read_csv(data_path, sep=',')
# df_no_na = df[[col_smiles, col_target]].dropna()

# X = df_no_na[col_smiles]
# y = df_no_na[col_target].values

# print(X)

# %%
col_smiles = 'canonical_smiles'
col_target = 'bioactivity_class'

METRIC_ACCURACY = 'accuracy'
METRIC_F1_SCORE = 'f1-score'
METRIC_COHEN_KAPPA = 'Cohen kappa'
METRIC_CONFUSION_MATRIX = 'Confusion Matrix'


CLASSES = ['benign', 'malignant']
TEST_RATIO = 0.2
SEED = 0

data_path = '/content/data/abl_kinase-data.csv'

# %%
def read_data(data_path, col_smiles='smiles', col_target='HIV_active'):
    """Split original data into train data and test data.
    :param data_path: str, path to the a CSV data file
    :param col_smiles: str, name of smiles column
    :param col_target: str, name of target column
    :param test_ratio: float, proportion of the original data for testset, must be from 0 to 1
    :param seed: int, randomization seed for reproducibility
    :return (X, y)
    """
    

    # read data
    df = pd.read_csv(data_path, sep=',')
    df_no_na = df[[col_smiles, col_target]].dropna()

    X = df_no_na[col_smiles]
    y = df_no_na[col_target].values

    df['new_Bio'] = pd.factorize(df.bioactivity_class)[0]

    df.head()

    y = df['new_Bio'].values

    return X, y

                
def get_prediction_score(y_label, y_predict):
    """Evaluate predictions using different evaluation metrics.
    :param y_label: list, contains true label
    :param y_predict: list, contains predicted label
    :return scores: dict, evaluation metrics on the prediction
    """
    scores = {}
    scores[METRIC_ACCURACY] = accuracy_score(y_label, y_predict)
    scores[METRIC_F1_SCORE] = f1_score(y_label, y_predict, labels=None, average='macro', sample_weight=None)
    scores[METRIC_COHEN_KAPPA] = cohen_kappa_score(y_label, y_predict)
    scores[METRIC_CONFUSION_MATRIX] = confusion_matrix(y_label, y_predict)
    
    return scores

# %%
import os
import sys
sys.path.insert(0, os.getcwd()) # add current working directory to pythonpath



import tensorflow as tf

from tensorflow.python.keras import backend as K
#os.environ["CUDA_VISIBLE_DEVICES"]="0" # Use only the 1st GPU
tf_config = tf.compat.v1.ConfigProto()
sess = tf.compat.v1.Session(config=tf_config)
K.set_session(sess)


from tensorflow.keras import callbacks
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Flatten
from tensorflow.keras.layers import Embedding, LSTM, GlobalMaxPooling1D, SpatialDropout1D, Conv1D, MaxPooling1D, GRU, Bidirectional
from tensorflow.keras import optimizers
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight


import warnings
import gc

# %%
# import os
# import sys
# sys.path.insert(0, os.getcwd()) # add current working directory to pythonpath



# import keras.backend as K
# import numpy as np
# import tensorflow as tf
# from keras import callbacks
# from keras.optimizers import Adam
# from keras.models import load_model
# from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
# from keras.models import Sequential
# from keras.models import Model
# from keras.layers import Input, Dense, Dropout, BatchNormalization, Flatten
# from keras.layers import Embedding, LSTM, GlobalMaxPooling1D, SpatialDropout1D, Conv1D, MaxPooling1D, GRU, Bidirectional
# from keras import optimizers
# from sklearn.model_selection import train_test_split
# from sklearn.utils import class_weight

# import warnings
# import argparse
# import gc

# %%
def generate_tokens(smiles, len_percentile=100):
    """
    Generate character tokens from smiles
    :param smiles: Pandas series, containing smiles
    :param len_percentile: percentile of smiles length to set as max length
    :return tokens
    :return num_words
    :return max_phrase_len
    """ 
    
    # Get max length of smiles
    smiles_len = smiles.apply(lambda p: len(p))
    max_phrase_len = int(np.percentile(smiles_len, len_percentile))
    print('True max length is ' + str(np.max(smiles_len)) + ', ' + str(max_phrase_len) + ' is set the length cutoff.')
        
    # Get unique words
    unique_words = np.unique(np.concatenate(smiles.apply(lambda p: np.array(list(p))).values, axis=0))
    num_words = len(unique_words)
    print('Vocab size is ' + str(num_words))
    
    tokenizer = Tokenizer(
        num_words = num_words,
        filters = '$',
        char_level = True,
        oov_token = '_'
    )

    #print(num_words)
    
    tokenizer.fit_on_texts(smiles)
    sequences = tokenizer.texts_to_sequences(smiles)
    tokens = pad_sequences(sequences, maxlen = max_phrase_len, padding='post', truncating='post')
    
    return tokens, num_words, max_phrase_len

# %%
smiles, y = read_data(data_path, col_smiles='canonical_smiles', col_target='bioactivity_class')
tokens, num_words, max_phrase_len = generate_tokens(smiles, len_percentile=100)
# Out:
# True max length is 254, 254 is set the length cutoff.
# Vocab size is 35

# %%
def create_model(model_type, num_words, input_length, output_dim=1, dropout_rate=0.0):
    """Build different sequence model
    :param model_type: str, can be 'cnn-gru', 'cnn', 'gru', 'lstm'
    :param num_words: int
    :param input_length: int
    :param output_dim: int
    :return model: Keras model
    """ 
    
    model = Sequential()
    if model_type == 'lstm': # LSTM - LSTM
        model.add(Embedding(num_words+1, 50, input_length=input_length))
        model.add(Bidirectional(LSTM(128, return_sequences=True)))
        model.add(Bidirectional(LSTM(128)))
        model.add(Dense(128, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(output_dim, activation='sigmoid'))
    elif model_type == 'gru': # GRU - GRU
        model.add(Embedding(num_words+1, 50, input_length=input_length))
        model.add(Bidirectional(GRU(128, return_sequences=True)))
        model.add(Bidirectional(GRU(128)))
        model.add(Dense(128, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(output_dim, activation='sigmoid'))
    elif model_type == 'cnn-gru': # 1D CNN - GRU
        model.add(Embedding(num_words+1, 50, input_length=input_length))
        model.add(Conv1D(192,3,activation='relu'))
        model.add(Bidirectional(GRU(224, return_sequences=True)))
        model.add(Bidirectional(GRU(384)))
        model.add(Dense(128, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(output_dim, activation='sigmoid'))
    elif model_type == 'cnn': # 1D CNN
        model.add(Embedding(num_words+1, 50, input_length=input_length))
        model.add(Conv1D(192, 10, activation='relu'))
        model.add(BatchNormalization())
        model.add(Conv1D(192, 3, activation='relu'))
        model.add(Flatten())
        model.add(Dense(128, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(output_dim, activation='sigmoid'))
    elif model_type == 'cnn-lstm': # 1D CNN - LSTM
        model.add(Embedding(num_words+1, 50, input_length=input_length))
        model.add(Conv1D(192,3,activation='relu'))
        model.add(Bidirectional(LSTM(224, return_sequences=True)))
        model.add(Bidirectional(LSTM(384)))
        model.add(Dense(128, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(output_dim, activation='sigmoid'))
    else:
        #raise ValueError(model_type + ' is not supported.')
        print('wrong model')
 
    model.summary()    
    return model

# %%
# def build_sequence_model(trainset, testset, model_type, num_words, input_length, output_dim=1, dropout_rate=0.0,
#                      batch_size=32, nb_epochs=100, lr=0.001):
#     """Train and evaluate CNN model
#     :param trainset: (X_train, y_train)
#     :param testset: (X_test, y_test)
#     :param model_type: str, can be 'cnn-gru', 'cnn', 'gru', 'lstm'
#     :param num_words: int
#     :param input_length: int
#     :param output_dim: int
#     :param batch_size: int, batch size for model training
#     :param nb_epochs: int, number of training epoches
#     :param lr: float, learning rate
#     :param save_path: path to save model
#     :return model: fitted Keras model
#     :return scores: dict, scores on test set for the fitted Keras model
#     """
    
#     # Create model
#     model = create_model(model_type=model_type, num_words=num_words, input_length=input_length, output_dim=output_dim,
#                          dropout_rate=dropout_rate)
    
#     # Callback list
#     callback_list = []
#     # monitor val_loss and terminate training if no improvement
#     early_stop = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.00001, \
#                 patience=20, verbose=2, mode='auto', restore_best_weights=True)
#     callback_list.append(early_stop)
    
#     # if save_path is not None:
#     #     # save best model based on val_acc during training
#     #     checkpoint = callbacks.ModelCheckpoint(os.path.join(save_path, '.h5'), monitor='val_acc', \
#     #                 verbose=0, save_best_only=True, save_weights_only=False, mode='auto')
#     #     callback_list.append(checkpoint)
        
#     # Get train and test set
#     (X_train, y_train) = trainset
#     (X_test, y_test) = testset
    
#     # Compute class weights
#     weight_list = class_weight.compute_class_weight('balanced', np.unique(y_train), y_train)
#     weight_dict = {}
#     for i in range(len(np.unique(y_train))):
#         weight_dict[np.unique(y_train)[i]] = weight_list[i]
    
#     # Train only classification head
#     optimizer = Adam(lr=lr, decay=1e-6, momentum=0.9, nesterov=True)
#     model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
#     model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=nb_epochs, \
#                         class_weight=weight_dict, callbacks=callback_list, verbose=2)
    
#     # Evaluate model    
#     prediction = model.predict(X_test)
#     y_val_predict = (prediction > 0.5).astype('uint8')
#     with warnings.catch_warnings():
#         warnings.simplefilter('ignore')  # disable the warning on f1-score with not all labels
#         scores = get_prediction_score(y_val, y_val_predict)
        
#     return model, scores

# %%
def build_sequence_model(trainset, testset, model_type, num_words, input_length, output_dim=1, dropout_rate=0.0,
                     batch_size=32, nb_epochs=100, lr=0.001,
                     save_path=None):
    """Train and evaluate CNN model
    :param trainset: (X_train, y_train)
    :param testset: (X_test, y_test)
    :param model_type: str, can be 'cnn-gru', 'cnn', 'gru', 'lstm'
    :param num_words: int
    :param input_length: int
    :param output_dim: int
    :param batch_size: int, batch size for model training
    :param nb_epochs: int, number of training epoches
    :param lr: float, learning rate
    :param save_path: path to save model
    :return model: fitted Keras model
    :return scores: dict, scores on test set for the fitted Keras model
    """
    
    # Create model
    model = create_model(model_type=model_type, num_words=num_words, input_length=input_length, output_dim=output_dim,
                         dropout_rate=dropout_rate)
    
    # Callback list
    callback_list = []
    # monitor val_loss and terminate training if no improvement
    early_stop = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.00001, \
                patience=20, verbose=2, mode='auto', restore_best_weights=True)
    callback_list.append(early_stop)
    
    if save_path is not None:
        # save best model based on val_acc during training
        checkpoint = callbacks.ModelCheckpoint(os.path.join(save_path, model_type + '.h5'), monitor='val_acc', \
                    verbose=0, save_best_only=True, save_weights_only=False, mode='auto')
        callback_list.append(checkpoint)
        
    # Get train and test set
    (X_train, y_train) = trainset
    (X_test, y_test) = testset
    
    # Compute class weights
    weight_list = class_weight.compute_class_weight('balanced', np.unique(y_train), y_train)
    weight_dict = {}
    for i in range(len(np.unique(y_train))):
        weight_dict[np.unique(y_train)[i]] = weight_list[i]
    
    # Train only classification head
    optimizer = Adam(lr=lr, decay=1e-6)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=nb_epochs, \
                        class_weight=weight_dict, callbacks=callback_list, verbose=2)
    
    # Evaluate model    
    prediction = model.predict(X_test)
    y_val_predict = (prediction > 0.5).astype('uint8')
    y_val = y_test
    with warnings.catch_warnings():
        warnings.filterwarnings('ignore')  # disable the warning on f1-score with not all labels
        scores = get_prediction_score(y_val, y_val_predict)
        
    return model, scores

# %%
data_path = '/content/data/abl_kinase-data.csv'


model_list = ['cnn', 'cnn-gru', 'gru', 'lstm', 'cnn-lstm']
batch_size = 16
nb_epochs = 100
lr = 0.001
save_path = '/content/data'

WORK_DIRECTORY = '/content/data'

# Make save_path
# if save_path is not None:
#     os.makedirs(os.path.join(save_path, 'sequence_models'), exist_ok=True)

# Read data
smiles, y = read_data(data_path, col_smiles='canonical_smiles', col_target='bioactivity_class')
tokens, num_words, max_phrase_len = generate_tokens(smiles, len_percentile=100)

# Get train and test set
X_train, X_test, y_train, y_test = train_test_split(tokens, y, test_size=TEST_RATIO, shuffle=True, stratify=y,
                                                  random_state=SEED)

# Build en evaluate graph models
model_scores = []
for model_type in model_list:
    model, scores = build_sequence_model((X_train, y_train), (X_test, y_test), model_type, num_words, max_phrase_len,
                                          output_dim=1, dropout_rate=0.0,
                                          batch_size=batch_size, nb_epochs=nb_epochs, lr=lr,
                             save_path=os.path.join(save_path, 'sequence_models', model_type + '.h5'))
    model_scores.append(scores)
        
    # force release memory
    K.clear_session()
    del model
    gc.collect()

model_df = pd.DataFrame({'model': model_list,

                    METRIC_ACCURACY: [score[METRIC_ACCURACY] for score in model_scores],
                    METRIC_F1_SCORE: [score[METRIC_F1_SCORE] for score in model_scores],
                    METRIC_COHEN_KAPPA: [score[METRIC_COHEN_KAPPA] for score in model_scores],
                    METRIC_CONFUSION_MATRIX: [score[METRIC_CONFUSION_MATRIX] for score in model_scores]                            
                      })
model_df = model_df[['model', METRIC_ACCURACY, METRIC_F1_SCORE, METRIC_COHEN_KAPPA,
                      METRIC_CONFUSION_MATRIX]]


model_df.to_csv(os.path.join(WORK_DIRECTORY, 'summary_sequence_model.csv'), index=False)
model_df.sort_values(by=[METRIC_ACCURACY, METRIC_F1_SCORE, METRIC_COHEN_KAPPA],
                      ascending=False, inplace=True)
print('Best model:\n' + str(model_df.iloc[0]))

print(model_df)

# !cp -r /content/data /content/drive/MyDrive/sequenceModelResults0
# Out:
# True max length is 254, 254 is set the length cutoff.
# Vocab size is 35
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 254, 50)           1800
# _________________________________________________________________
# conv1d (Conv1D)              (None, 245, 192)          96192
# _________________________________________________________________
# batch_normalization (BatchNo (None, 245, 192)          768
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 243, 192)          110784
# _________________________________________________________________
# flatten (Flatten)            (None, 46656)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5972096
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 6,181,769
# Trainable params: 6,181,385
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 54/54 - 34s - loss: 0.6429 - accuracy: 0.6925 - val_loss: 0.7122 - val_accuracy: 0.2245
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 54/54 - 1s - loss: 0.3151 - accuracy: 0.8384 - val_loss: 0.6848 - val_accuracy: 0.6019
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 54/54 - 1s - loss: 0.2201 - accuracy: 0.9021 - val_loss: 0.6247 - val_accuracy: 0.8125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 54/54 - 1s - loss: 0.1636 - accuracy: 0.9294 - val_loss: 0.5607 - val_accuracy: 0.8796
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 54/54 - 1s - loss: 0.1148 - accuracy: 0.9554 - val_loss: 0.5264 - val_accuracy: 0.8542
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 54/54 - 1s - loss: 0.1022 - accuracy: 0.9635 - val_loss: 0.4349 - val_accuracy: 0.8819
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 54/54 - 1s - loss: 0.1019 - accuracy: 0.9670 - val_loss: 0.4195 - val_accuracy: 0.8773
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 54/54 - 1s - loss: 0.0632 - accuracy: 0.9774 - val_loss: 0.2973 - val_accuracy: 0.8819
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 54/54 - 1s - loss: 0.0628 - accuracy: 0.9797 - val_loss: 0.2799 - val_accuracy: 0.8866
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 54/54 - 1s - loss: 0.0424 - accuracy: 0.9832 - val_loss: 0.2759 - val_accuracy: 0.8889
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 54/54 - 1s - loss: 0.0398 - accuracy: 0.9873 - val_loss: 0.2780 - val_accuracy: 0.8912
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 54/54 - 1s - loss: 0.0351 - accuracy: 0.9855 - val_loss: 0.2960 - val_accuracy: 0.8935
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 54/54 - 1s - loss: 0.0367 - accuracy: 0.9849 - val_loss: 0.3932 - val_accuracy: 0.8704
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 54/54 - 1s - loss: 0.0468 - accuracy: 0.9844 - val_loss: 0.3727 - val_accuracy: 0.8773
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 54/54 - 1s - loss: 0.0297 - accuracy: 0.9867 - val_loss: 0.4965 - val_accuracy: 0.8750
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 54/54 - 1s - loss: 0.0325 - accuracy: 0.9884 - val_loss: 0.4153 - val_accuracy: 0.8819
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 54/54 - 1s - loss: 0.0264 - accuracy: 0.9751 - val_loss: 0.4826 - val_accuracy: 0.8773
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 54/54 - 1s - loss: 0.0262 - accuracy: 0.9751 - val_loss: 0.5077 - val_accuracy: 0.8704
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 54/54 - 1s - loss: 0.0249 - accuracy: 0.9815 - val_loss: 0.5335 - val_accuracy: 0.8843
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 54/54 - 1s - loss: 0.0246 - accuracy: 0.9890 - val_loss: 0.5445 - val_accuracy: 0.8866
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 54/54 - 1s - loss: 0.0246 - accuracy: 0.9896 - val_loss: 0.5160 - val_accuracy: 0.8889
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 54/54 - 1s - loss: 0.0246 - accuracy: 0.9890 - val_loss: 0.5511 - val_accuracy: 0.8843
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 54/54 - 1s - loss: 0.0285 - accuracy: 0.9873 - val_loss: 0.5304 - val_accuracy: 0.8819
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# 54/54 - 1s - loss: 0.0242 - accuracy: 0.9890 - val_loss: 0.4818 - val_accuracy: 0.8935
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# 54/54 - 1s - loss: 0.0237 - accuracy: 0.9902 - val_loss: 0.5396 - val_accuracy: 0.8912
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# 54/54 - 1s - loss: 0.0230 - accuracy: 0.9902 - val_loss: 0.5570 - val_accuracy: 0.8935
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/100
# 54/54 - 1s - loss: 0.0226 - accuracy: 0.9907 - val_loss: 0.5368 - val_accuracy: 0.8819
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/100
# 54/54 - 1s - loss: 0.0232 - accuracy: 0.9896 - val_loss: 0.5771 - val_accuracy: 0.8889
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/100
# 54/54 - 1s - loss: 0.0245 - accuracy: 0.9890 - val_loss: 0.5097 - val_accuracy: 0.8912
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/100
# 54/54 - 1s - loss: 0.0234 - accuracy: 0.9890 - val_loss: 0.4972 - val_accuracy: 0.8819
# Restoring model weights from the end of the best epoch.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00030: early stopping
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 254, 50)           1800
# _________________________________________________________________
# conv1d (Conv1D)              (None, 252, 192)          28992
# _________________________________________________________________
# bidirectional (Bidirectional (None, 252, 448)          561792
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 768)               1921536
# _________________________________________________________________
# dense (Dense)                (None, 128)               98432
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,612,681
# Trainable params: 2,612,681
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 54/54 - 10s - loss: 0.6876 - accuracy: 0.5565 - val_loss: 0.5743 - val_accuracy: 0.7708
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 54/54 - 4s - loss: 0.6454 - accuracy: 0.6537 - val_loss: 0.6940 - val_accuracy: 0.4884
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 54/54 - 5s - loss: 0.5811 - accuracy: 0.7661 - val_loss: 0.6662 - val_accuracy: 0.6227
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 54/54 - 5s - loss: 0.5420 - accuracy: 0.7417 - val_loss: 0.5514 - val_accuracy: 0.7685
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 54/54 - 5s - loss: 0.5817 - accuracy: 0.7157 - val_loss: 0.4909 - val_accuracy: 0.7546
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 54/54 - 5s - loss: 0.5258 - accuracy: 0.7076 - val_loss: 0.4875 - val_accuracy: 0.7477
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 54/54 - 5s - loss: 0.5012 - accuracy: 0.7632 - val_loss: 0.5375 - val_accuracy: 0.7477
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 54/54 - 5s - loss: 0.4779 - accuracy: 0.7568 - val_loss: 0.4839 - val_accuracy: 0.7685
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 54/54 - 5s - loss: 0.4603 - accuracy: 0.7788 - val_loss: 0.4665 - val_accuracy: 0.7616
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 54/54 - 5s - loss: 0.4524 - accuracy: 0.7522 - val_loss: 0.4819 - val_accuracy: 0.7639
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 54/54 - 5s - loss: 0.4084 - accuracy: 0.7742 - val_loss: 0.5231 - val_accuracy: 0.6921
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 54/54 - 5s - loss: 0.3711 - accuracy: 0.7875 - val_loss: 0.4261 - val_accuracy: 0.8009
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 54/54 - 5s - loss: 0.3934 - accuracy: 0.7887 - val_loss: 0.3725 - val_accuracy: 0.8426
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 54/54 - 5s - loss: 0.3789 - accuracy: 0.7962 - val_loss: 0.4319 - val_accuracy: 0.7917
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 54/54 - 5s - loss: 0.3295 - accuracy: 0.8425 - val_loss: 0.4018 - val_accuracy: 0.8148
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 54/54 - 5s - loss: 0.3339 - accuracy: 0.8338 - val_loss: 0.4552 - val_accuracy: 0.8009
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 54/54 - 5s - loss: 0.3612 - accuracy: 0.8153 - val_loss: 0.3936 - val_accuracy: 0.7940
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 54/54 - 5s - loss: 0.3437 - accuracy: 0.8263 - val_loss: 0.5839 - val_accuracy: 0.6875
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 54/54 - 5s - loss: 0.3002 - accuracy: 0.8541 - val_loss: 0.4173 - val_accuracy: 0.7847
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 54/54 - 5s - loss: 0.2906 - accuracy: 0.8512 - val_loss: 0.4698 - val_accuracy: 0.7523
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 54/54 - 5s - loss: 0.2555 - accuracy: 0.8807 - val_loss: 0.4021 - val_accuracy: 0.8148
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 54/54 - 5s - loss: 0.2505 - accuracy: 0.8790 - val_loss: 0.4033 - val_accuracy: 0.8356
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 54/54 - 5s - loss: 0.2132 - accuracy: 0.8981 - val_loss: 0.3749 - val_accuracy: 0.8380
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# 54/54 - 5s - loss: 0.2067 - accuracy: 0.9091 - val_loss: 0.4114 - val_accuracy: 0.8426
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# 54/54 - 5s - loss: 0.2340 - accuracy: 0.8975 - val_loss: 0.4524 - val_accuracy: 0.7662
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# 54/54 - 5s - loss: 0.2876 - accuracy: 0.8610 - val_loss: 0.4894 - val_accuracy: 0.8056
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/100
# 54/54 - 5s - loss: 0.1982 - accuracy: 0.9189 - val_loss: 0.3623 - val_accuracy: 0.8588
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/100
# 54/54 - 5s - loss: 0.2152 - accuracy: 0.9074 - val_loss: 0.3462 - val_accuracy: 0.8519
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/100
# 54/54 - 5s - loss: 0.1785 - accuracy: 0.9201 - val_loss: 0.3589 - val_accuracy: 0.8681
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/100
# 54/54 - 5s - loss: 0.1615 - accuracy: 0.9363 - val_loss: 0.4237 - val_accuracy: 0.8519
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 31/100
# 54/54 - 5s - loss: 0.2070 - accuracy: 0.9079 - val_loss: 0.3872 - val_accuracy: 0.8426
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 32/100
# 54/54 - 5s - loss: 0.1634 - accuracy: 0.9282 - val_loss: 0.5007 - val_accuracy: 0.8079
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 33/100
# 54/54 - 5s - loss: 0.1713 - accuracy: 0.9224 - val_loss: 0.3402 - val_accuracy: 0.8796
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 34/100
# 54/54 - 5s - loss: 0.1277 - accuracy: 0.9438 - val_loss: 0.3752 - val_accuracy: 0.8657
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 35/100
# 54/54 - 5s - loss: 0.1210 - accuracy: 0.9485 - val_loss: 0.4791 - val_accuracy: 0.8611
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 36/100
# 54/54 - 5s - loss: 0.1545 - accuracy: 0.9415 - val_loss: 0.2991 - val_accuracy: 0.8727
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 37/100
# 54/54 - 5s - loss: 0.1195 - accuracy: 0.9496 - val_loss: 0.3636 - val_accuracy: 0.8773
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 38/100
# 54/54 - 5s - loss: 0.0948 - accuracy: 0.9653 - val_loss: 0.3980 - val_accuracy: 0.8681
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 39/100
# 54/54 - 5s - loss: 0.0708 - accuracy: 0.9699 - val_loss: 0.4249 - val_accuracy: 0.8819
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 40/100
# 54/54 - 5s - loss: 0.0580 - accuracy: 0.9745 - val_loss: 0.4233 - val_accuracy: 0.8796
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 41/100
# 54/54 - 5s - loss: 0.0688 - accuracy: 0.9722 - val_loss: 0.3934 - val_accuracy: 0.8912
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 42/100
# 54/54 - 5s - loss: 0.1395 - accuracy: 0.9427 - val_loss: 0.3935 - val_accuracy: 0.8611
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 43/100
# 54/54 - 5s - loss: 0.1634 - accuracy: 0.9294 - val_loss: 0.3126 - val_accuracy: 0.8796
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 44/100
# 54/54 - 5s - loss: 0.0950 - accuracy: 0.9583 - val_loss: 0.3509 - val_accuracy: 0.8935
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 45/100
# 54/54 - 5s - loss: 0.0834 - accuracy: 0.9676 - val_loss: 0.4271 - val_accuracy: 0.8912
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 46/100
# 54/54 - 5s - loss: 0.0754 - accuracy: 0.9670 - val_loss: 0.3990 - val_accuracy: 0.8819
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 47/100
# 54/54 - 5s - loss: 0.0682 - accuracy: 0.9734 - val_loss: 0.4888 - val_accuracy: 0.8681
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 48/100
# 54/54 - 5s - loss: 0.0506 - accuracy: 0.9768 - val_loss: 0.3732 - val_accuracy: 0.8912
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 49/100
# 54/54 - 5s - loss: 0.0815 - accuracy: 0.9658 - val_loss: 0.4706 - val_accuracy: 0.8750
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 50/100
# 54/54 - 5s - loss: 0.0585 - accuracy: 0.9705 - val_loss: 0.4929 - val_accuracy: 0.8889
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 51/100
# 54/54 - 5s - loss: 0.0387 - accuracy: 0.9855 - val_loss: 0.5041 - val_accuracy: 0.8958
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 52/100
# 54/54 - 5s - loss: 0.0330 - accuracy: 0.9873 - val_loss: 0.4831 - val_accuracy: 0.8981
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 53/100
# 54/54 - 5s - loss: 0.0290 - accuracy: 0.9896 - val_loss: 0.5143 - val_accuracy: 0.8866
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 54/100
# 54/54 - 5s - loss: 0.0261 - accuracy: 0.9878 - val_loss: 0.5135 - val_accuracy: 0.8866
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 55/100
# 54/54 - 5s - loss: 0.0241 - accuracy: 0.9884 - val_loss: 0.5371 - val_accuracy: 0.8912
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 56/100
# 54/54 - 5s - loss: 0.0264 - accuracy: 0.9832 - val_loss: 0.5327 - val_accuracy: 0.8958
# Restoring model weights from the end of the best epoch.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00056: early stopping
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 254, 50)           1800
# _________________________________________________________________
# bidirectional (Bidirectional (None, 254, 256)          138240
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               296448
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 469,513
# Trainable params: 469,513
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 54/54 - 8s - loss: 0.6874 - accuracy: 0.4910 - val_loss: 0.7098 - val_accuracy: 0.4514
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 54/54 - 2s - loss: 0.6577 - accuracy: 0.5507 - val_loss: 0.5833 - val_accuracy: 0.7222
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 54/54 - 2s - loss: 0.6496 - accuracy: 0.6225 - val_loss: 0.6281 - val_accuracy: 0.6806
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 54/54 - 2s - loss: 0.6162 - accuracy: 0.6167 - val_loss: 0.9502 - val_accuracy: 0.4097
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 54/54 - 2s - loss: 0.6845 - accuracy: 0.5802 - val_loss: 0.6978 - val_accuracy: 0.6968
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 54/54 - 2s - loss: 0.6324 - accuracy: 0.7221 - val_loss: 0.8876 - val_accuracy: 0.4722
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 54/54 - 2s - loss: 0.5588 - accuracy: 0.6804 - val_loss: 0.5829 - val_accuracy: 0.7083
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 54/54 - 2s - loss: 0.5168 - accuracy: 0.7197 - val_loss: 0.5382 - val_accuracy: 0.7176
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 54/54 - 2s - loss: 0.4777 - accuracy: 0.7284 - val_loss: 0.5474 - val_accuracy: 0.7130
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 54/54 - 2s - loss: 0.4434 - accuracy: 0.7585 - val_loss: 0.4737 - val_accuracy: 0.7384
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 54/54 - 2s - loss: 0.4290 - accuracy: 0.7759 - val_loss: 0.5288 - val_accuracy: 0.7292
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 54/54 - 2s - loss: 0.4259 - accuracy: 0.7759 - val_loss: 0.5006 - val_accuracy: 0.7361
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 54/54 - 2s - loss: 0.4188 - accuracy: 0.7915 - val_loss: 0.5301 - val_accuracy: 0.7199
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 54/54 - 2s - loss: 0.4110 - accuracy: 0.7910 - val_loss: 0.4364 - val_accuracy: 0.7454
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 54/54 - 2s - loss: 0.4139 - accuracy: 0.8008 - val_loss: 0.4748 - val_accuracy: 0.7569
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 54/54 - 2s - loss: 0.4156 - accuracy: 0.7765 - val_loss: 0.4293 - val_accuracy: 0.7569
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 54/54 - 2s - loss: 0.4237 - accuracy: 0.7823 - val_loss: 0.5565 - val_accuracy: 0.7222
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 54/54 - 2s - loss: 0.3854 - accuracy: 0.8060 - val_loss: 0.4748 - val_accuracy: 0.7454
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 54/54 - 2s - loss: 0.3720 - accuracy: 0.8269 - val_loss: 0.4796 - val_accuracy: 0.7986
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 54/54 - 2s - loss: 0.3336 - accuracy: 0.8419 - val_loss: 0.4334 - val_accuracy: 0.7870
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 54/54 - 2s - loss: 0.3685 - accuracy: 0.8269 - val_loss: 0.5355 - val_accuracy: 0.7523
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 54/54 - 2s - loss: 0.4194 - accuracy: 0.7719 - val_loss: 0.4168 - val_accuracy: 0.7940
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 54/54 - 2s - loss: 0.3283 - accuracy: 0.8425 - val_loss: 0.4708 - val_accuracy: 0.8171
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# 54/54 - 2s - loss: 0.2906 - accuracy: 0.8523 - val_loss: 0.3919 - val_accuracy: 0.8148
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# 54/54 - 2s - loss: 0.2801 - accuracy: 0.8651 - val_loss: 0.4092 - val_accuracy: 0.7894
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# 54/54 - 2s - loss: 0.2825 - accuracy: 0.8703 - val_loss: 0.4009 - val_accuracy: 0.8310
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/100
# 54/54 - 2s - loss: 0.2397 - accuracy: 0.8836 - val_loss: 0.4317 - val_accuracy: 0.7894
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/100
# 54/54 - 2s - loss: 0.2599 - accuracy: 0.8749 - val_loss: 0.4603 - val_accuracy: 0.8264
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/100
# 54/54 - 2s - loss: 0.2365 - accuracy: 0.8801 - val_loss: 0.3371 - val_accuracy: 0.8565
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/100
# 54/54 - 2s - loss: 0.2153 - accuracy: 0.8969 - val_loss: 0.3992 - val_accuracy: 0.8218
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 31/100
# 54/54 - 2s - loss: 0.1996 - accuracy: 0.8917 - val_loss: 0.3826 - val_accuracy: 0.8333
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 32/100
# 54/54 - 2s - loss: 0.1892 - accuracy: 0.9056 - val_loss: 0.3953 - val_accuracy: 0.8333
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 33/100
# 54/54 - 2s - loss: 0.1792 - accuracy: 0.9033 - val_loss: 0.3665 - val_accuracy: 0.8565
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 34/100
# 54/54 - 2s - loss: 0.1853 - accuracy: 0.9079 - val_loss: 0.4652 - val_accuracy: 0.8264
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 35/100
# 54/54 - 2s - loss: 0.1858 - accuracy: 0.9050 - val_loss: 0.3603 - val_accuracy: 0.8403
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 36/100
# 54/54 - 2s - loss: 0.1537 - accuracy: 0.9207 - val_loss: 0.3721 - val_accuracy: 0.8588
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 37/100
# 54/54 - 2s - loss: 0.1901 - accuracy: 0.9039 - val_loss: 0.3850 - val_accuracy: 0.8495
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 38/100
# 54/54 - 2s - loss: 0.1602 - accuracy: 0.9247 - val_loss: 0.4480 - val_accuracy: 0.8565
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 39/100
# 54/54 - 2s - loss: 0.1389 - accuracy: 0.9311 - val_loss: 0.3620 - val_accuracy: 0.8588
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 40/100
# 54/54 - 2s - loss: 0.1043 - accuracy: 0.9502 - val_loss: 0.4226 - val_accuracy: 0.8403
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 41/100
# 54/54 - 2s - loss: 0.1548 - accuracy: 0.9386 - val_loss: 0.7442 - val_accuracy: 0.7824
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 42/100
# 54/54 - 2s - loss: 0.1838 - accuracy: 0.9108 - val_loss: 0.4057 - val_accuracy: 0.8657
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 43/100
# 54/54 - 2s - loss: 0.1410 - accuracy: 0.9311 - val_loss: 0.3529 - val_accuracy: 0.8634
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 44/100
# 54/54 - 2s - loss: 0.1041 - accuracy: 0.9502 - val_loss: 0.3869 - val_accuracy: 0.8611
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 45/100
# 54/54 - 2s - loss: 0.0980 - accuracy: 0.9531 - val_loss: 0.3897 - val_accuracy: 0.8796
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 46/100
# 54/54 - 2s - loss: 0.0795 - accuracy: 0.9653 - val_loss: 0.4492 - val_accuracy: 0.8750
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 47/100
# 54/54 - 2s - loss: 0.0749 - accuracy: 0.9676 - val_loss: 0.4361 - val_accuracy: 0.8750
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 48/100
# 54/54 - 2s - loss: 0.1113 - accuracy: 0.9508 - val_loss: 0.3797 - val_accuracy: 0.8750
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 49/100
# 54/54 - 2s - loss: 0.1584 - accuracy: 0.9334 - val_loss: 1.5368 - val_accuracy: 0.3889
# Restoring model weights from the end of the best epoch.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00049: early stopping
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 254, 50)           1800
# _________________________________________________________________
# bidirectional (Bidirectional (None, 254, 256)          183296
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               394240
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 612,361
# Trainable params: 612,361
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 54/54 - 8s - loss: 0.7096 - accuracy: 0.4627 - val_loss: 0.8002 - val_accuracy: 0.1875
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 54/54 - 3s - loss: 0.7119 - accuracy: 0.5165 - val_loss: 0.8131 - val_accuracy: 0.1875
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 54/54 - 3s - loss: 0.6997 - accuracy: 0.4933 - val_loss: 0.6914 - val_accuracy: 0.5000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 54/54 - 3s - loss: 0.6955 - accuracy: 0.4708 - val_loss: 0.6572 - val_accuracy: 0.8125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 54/54 - 2s - loss: 0.6941 - accuracy: 0.5177 - val_loss: 0.6797 - val_accuracy: 0.4491
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 54/54 - 3s - loss: 0.6777 - accuracy: 0.4603 - val_loss: 0.6067 - val_accuracy: 0.8125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 54/54 - 3s - loss: 0.6831 - accuracy: 0.4933 - val_loss: 0.7692 - val_accuracy: 0.3981
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 54/54 - 3s - loss: 0.6814 - accuracy: 0.4598 - val_loss: 0.6060 - val_accuracy: 0.8125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 54/54 - 2s - loss: 0.6879 - accuracy: 0.5252 - val_loss: 0.6513 - val_accuracy: 0.4653
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 54/54 - 3s - loss: 0.6748 - accuracy: 0.4754 - val_loss: 0.6285 - val_accuracy: 0.4653
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 54/54 - 3s - loss: 0.6750 - accuracy: 0.4233 - val_loss: 0.5932 - val_accuracy: 0.5000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 54/54 - 3s - loss: 0.6755 - accuracy: 0.4244 - val_loss: 0.6352 - val_accuracy: 0.4653
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 54/54 - 3s - loss: 0.6753 - accuracy: 0.4273 - val_loss: 0.6695 - val_accuracy: 0.4676
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 54/54 - 2s - loss: 0.6759 - accuracy: 0.4140 - val_loss: 0.6570 - val_accuracy: 0.4653
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 54/54 - 3s - loss: 0.6691 - accuracy: 0.4644 - val_loss: 0.6358 - val_accuracy: 0.5255
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 54/54 - 3s - loss: 0.6665 - accuracy: 0.5547 - val_loss: 0.6429 - val_accuracy: 0.6505
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 54/54 - 2s - loss: 0.6628 - accuracy: 0.5924 - val_loss: 0.6543 - val_accuracy: 0.6319
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 54/54 - 2s - loss: 0.6530 - accuracy: 0.6456 - val_loss: 0.6822 - val_accuracy: 0.6088
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 54/54 - 2s - loss: 0.6789 - accuracy: 0.6144 - val_loss: 0.5856 - val_accuracy: 0.5787
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 54/54 - 3s - loss: 0.6746 - accuracy: 0.4632 - val_loss: 0.5517 - val_accuracy: 0.8125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 54/54 - 2s - loss: 0.6611 - accuracy: 0.6404 - val_loss: 0.6846 - val_accuracy: 0.5556
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 54/54 - 3s - loss: 0.6513 - accuracy: 0.6306 - val_loss: 0.6035 - val_accuracy: 0.7199
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 54/54 - 3s - loss: 0.6235 - accuracy: 0.6647 - val_loss: 0.5690 - val_accuracy: 0.7500
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# 54/54 - 3s - loss: 0.6040 - accuracy: 0.7018 - val_loss: 0.6168 - val_accuracy: 0.6921
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# 54/54 - 3s - loss: 0.5926 - accuracy: 0.7331 - val_loss: 0.5192 - val_accuracy: 0.8194
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# 54/54 - 2s - loss: 0.5973 - accuracy: 0.7169 - val_loss: 0.6492 - val_accuracy: 0.7060
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/100
# 54/54 - 2s - loss: 0.5838 - accuracy: 0.7058 - val_loss: 0.5182 - val_accuracy: 0.7801
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/100
# 54/54 - 2s - loss: 0.5723 - accuracy: 0.7522 - val_loss: 0.5177 - val_accuracy: 0.7870
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/100
# 54/54 - 2s - loss: 0.5492 - accuracy: 0.7597 - val_loss: 0.5471 - val_accuracy: 0.7847
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/100
# 54/54 - 2s - loss: 0.5359 - accuracy: 0.7869 - val_loss: 0.5675 - val_accuracy: 0.7639
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 31/100
# 54/54 - 3s - loss: 0.5366 - accuracy: 0.7973 - val_loss: 0.6481 - val_accuracy: 0.7199
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 32/100
# 54/54 - 2s - loss: 0.5362 - accuracy: 0.7690 - val_loss: 0.5207 - val_accuracy: 0.7801
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 33/100
# 54/54 - 3s - loss: 0.5083 - accuracy: 0.8002 - val_loss: 0.6105 - val_accuracy: 0.7245
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 34/100
# 54/54 - 3s - loss: 0.5358 - accuracy: 0.7643 - val_loss: 0.5881 - val_accuracy: 0.7662
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 35/100
# 54/54 - 3s - loss: 0.4995 - accuracy: 0.7753 - val_loss: 0.4113 - val_accuracy: 0.8380
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 36/100
# 54/54 - 3s - loss: 0.5004 - accuracy: 0.7863 - val_loss: 0.5658 - val_accuracy: 0.7477
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 37/100
# 54/54 - 3s - loss: 0.4406 - accuracy: 0.8025 - val_loss: 0.5266 - val_accuracy: 0.7870
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 38/100
# 54/54 - 3s - loss: 0.4507 - accuracy: 0.7997 - val_loss: 0.4273 - val_accuracy: 0.7940
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 39/100
# 54/54 - 2s - loss: 0.3932 - accuracy: 0.8298 - val_loss: 0.4944 - val_accuracy: 0.7847
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 40/100
# 54/54 - 2s - loss: 0.3758 - accuracy: 0.8292 - val_loss: 0.4012 - val_accuracy: 0.8310
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 41/100
# 54/54 - 2s - loss: 0.3991 - accuracy: 0.8078 - val_loss: 0.3852 - val_accuracy: 0.8380
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 42/100
# 54/54 - 2s - loss: 0.3524 - accuracy: 0.8298 - val_loss: 0.5293 - val_accuracy: 0.7569
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 43/100
# 54/54 - 2s - loss: 0.3378 - accuracy: 0.8246 - val_loss: 0.4315 - val_accuracy: 0.7847
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 44/100
# 54/54 - 2s - loss: 0.3488 - accuracy: 0.8280 - val_loss: 0.4125 - val_accuracy: 0.8218
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 45/100
# 54/54 - 2s - loss: 0.3260 - accuracy: 0.8466 - val_loss: 0.3474 - val_accuracy: 0.8403
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 46/100
# 54/54 - 2s - loss: 0.3124 - accuracy: 0.8512 - val_loss: 0.4259 - val_accuracy: 0.8148
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 47/100
# 54/54 - 2s - loss: 0.3002 - accuracy: 0.8645 - val_loss: 0.4444 - val_accuracy: 0.7940
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 48/100
# 54/54 - 2s - loss: 0.2936 - accuracy: 0.8593 - val_loss: 0.3983 - val_accuracy: 0.8102
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 49/100
# 54/54 - 3s - loss: 0.2783 - accuracy: 0.8697 - val_loss: 0.4200 - val_accuracy: 0.8056
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 50/100
# 54/54 - 3s - loss: 0.2763 - accuracy: 0.8662 - val_loss: 0.3465 - val_accuracy: 0.8287
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 51/100
# 54/54 - 3s - loss: 0.2884 - accuracy: 0.8651 - val_loss: 0.4238 - val_accuracy: 0.7940
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 52/100
# 54/54 - 2s - loss: 0.2462 - accuracy: 0.8720 - val_loss: 0.3953 - val_accuracy: 0.8565
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 53/100
# 54/54 - 2s - loss: 0.2523 - accuracy: 0.8755 - val_loss: 0.4280 - val_accuracy: 0.8380
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 54/100
# 54/54 - 2s - loss: 0.2487 - accuracy: 0.8819 - val_loss: 0.4700 - val_accuracy: 0.7963
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 55/100
# 54/54 - 3s - loss: 0.2211 - accuracy: 0.8888 - val_loss: 0.3840 - val_accuracy: 0.8079
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 56/100
# 54/54 - 2s - loss: 0.2264 - accuracy: 0.8842 - val_loss: 0.4468 - val_accuracy: 0.7894
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 57/100
# 54/54 - 2s - loss: 0.2294 - accuracy: 0.8871 - val_loss: 0.4482 - val_accuracy: 0.8079
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 58/100
# 54/54 - 3s - loss: 0.2052 - accuracy: 0.8964 - val_loss: 0.4308 - val_accuracy: 0.8125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 59/100
# 54/54 - 3s - loss: 0.1838 - accuracy: 0.9137 - val_loss: 0.4054 - val_accuracy: 0.8403
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 60/100
# 54/54 - 2s - loss: 0.1792 - accuracy: 0.9079 - val_loss: 0.3921 - val_accuracy: 0.8333
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 61/100
# 54/54 - 2s - loss: 0.3020 - accuracy: 0.8535 - val_loss: 0.5266 - val_accuracy: 0.7963
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 62/100
# 54/54 - 3s - loss: 0.3108 - accuracy: 0.8610 - val_loss: 0.3944 - val_accuracy: 0.8310
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 63/100
# 54/54 - 3s - loss: 0.2028 - accuracy: 0.9027 - val_loss: 0.4487 - val_accuracy: 0.8125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 64/100
# 54/54 - 3s - loss: 0.2139 - accuracy: 0.8969 - val_loss: 0.4519 - val_accuracy: 0.8218
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 65/100
# 54/54 - 3s - loss: 0.1772 - accuracy: 0.9126 - val_loss: 0.4398 - val_accuracy: 0.8171
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 66/100
# 54/54 - 3s - loss: 0.1653 - accuracy: 0.9201 - val_loss: 0.4452 - val_accuracy: 0.8449
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 67/100
# 54/54 - 3s - loss: 0.1643 - accuracy: 0.9288 - val_loss: 0.4284 - val_accuracy: 0.8449
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 68/100
# 54/54 - 3s - loss: 0.1559 - accuracy: 0.9299 - val_loss: 0.4395 - val_accuracy: 0.8333
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 69/100
# 54/54 - 3s - loss: 0.1609 - accuracy: 0.9218 - val_loss: 0.4121 - val_accuracy: 0.8426
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 70/100
# 54/54 - 3s - loss: 0.1648 - accuracy: 0.9155 - val_loss: 0.4251 - val_accuracy: 0.8449
# Restoring model weights from the end of the best epoch.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00070: early stopping
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 254, 50)           1800
# _________________________________________________________________
# conv1d (Conv1D)              (None, 252, 192)          28992
# _________________________________________________________________
# bidirectional (Bidirectional (None, 252, 448)          747264
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 768)               2558976
# _________________________________________________________________
# dense (Dense)                (None, 128)               98432
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 3,435,593
# Trainable params: 3,435,593
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 54/54 - 11s - loss: 0.7951 - accuracy: 0.4627 - val_loss: 0.6968 - val_accuracy: 0.3843
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 54/54 - 6s - loss: 0.5708 - accuracy: 0.6584 - val_loss: 0.4535 - val_accuracy: 0.7222
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 54/54 - 6s - loss: 0.5180 - accuracy: 0.7093 - val_loss: 0.4122 - val_accuracy: 0.7130
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 54/54 - 6s - loss: 0.7508 - accuracy: 0.5345 - val_loss: 0.6158 - val_accuracy: 0.8241
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 54/54 - 6s - loss: 0.7407 - accuracy: 0.5067 - val_loss: 1.1461 - val_accuracy: 0.1875
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 54/54 - 6s - loss: 0.7064 - accuracy: 0.4644 - val_loss: 0.4739 - val_accuracy: 0.8125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 54/54 - 6s - loss: 0.7463 - accuracy: 0.5588 - val_loss: 0.8460 - val_accuracy: 0.1875
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 54/54 - 6s - loss: 0.7103 - accuracy: 0.4586 - val_loss: 0.8937 - val_accuracy: 0.1875
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 54/54 - 6s - loss: 0.7043 - accuracy: 0.5373 - val_loss: 0.8170 - val_accuracy: 0.1875
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 54/54 - 6s - loss: 0.6944 - accuracy: 0.5472 - val_loss: 0.7456 - val_accuracy: 0.1875
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 54/54 - 6s - loss: 0.6797 - accuracy: 0.4957 - val_loss: 0.7010 - val_accuracy: 0.3843
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 54/54 - 6s - loss: 0.5804 - accuracy: 0.7360 - val_loss: 0.6030 - val_accuracy: 0.7083
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 54/54 - 6s - loss: 0.4990 - accuracy: 0.7319 - val_loss: 0.4673 - val_accuracy: 0.7292
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 54/54 - 6s - loss: 0.4762 - accuracy: 0.7470 - val_loss: 0.6478 - val_accuracy: 0.5556
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 54/54 - 6s - loss: 0.5282 - accuracy: 0.7169 - val_loss: 0.6048 - val_accuracy: 0.7384
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 54/54 - 6s - loss: 0.4821 - accuracy: 0.7695 - val_loss: 0.5518 - val_accuracy: 0.7153
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 54/54 - 6s - loss: 0.6132 - accuracy: 0.5767 - val_loss: 0.6125 - val_accuracy: 0.6250
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 54/54 - 6s - loss: 0.5361 - accuracy: 0.7423 - val_loss: 0.5897 - val_accuracy: 0.7037
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 54/54 - 6s - loss: 0.5637 - accuracy: 0.6398 - val_loss: 0.4525 - val_accuracy: 0.7431
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 54/54 - 6s - loss: 0.5210 - accuracy: 0.7510 - val_loss: 0.6527 - val_accuracy: 0.7338
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 54/54 - 6s - loss: 0.4935 - accuracy: 0.7614 - val_loss: 0.5620 - val_accuracy: 0.7315
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 54/54 - 6s - loss: 0.4735 - accuracy: 0.7852 - val_loss: 0.4620 - val_accuracy: 0.7593
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 54/54 - 6s - loss: 0.5610 - accuracy: 0.6867 - val_loss: 0.5369 - val_accuracy: 0.7245
# Restoring model weights from the end of the best epoch.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00023: early stopping
# Best model:
# model                                 cnn
# accuracy                         0.888889
# f1-score                         0.825783
# Cohen kappa                      0.651859
# Confusion Matrix    [[62, 19], [29, 322]]
# Name: 0, dtype: object
#       model  accuracy  f1-score  Cohen kappa        Confusion Matrix
# 0       cnn  0.888889  0.825783     0.651859   [[62, 19], [29, 322]]
# 1   cnn-gru  0.872685  0.799499     0.599271   [[58, 23], [32, 319]]
# 2       gru  0.856481  0.790848     0.584241   [[64, 17], [45, 306]]
# 3      lstm  0.828704  0.759277     0.523733   [[63, 18], [56, 295]]
# 4  cnn-lstm  0.712963  0.658889     0.357097  [[68, 13], [111, 240]]

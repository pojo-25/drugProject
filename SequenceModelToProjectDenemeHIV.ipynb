# %% [markdown]
# <a href="https://colab.research.google.com/github/pojo-25/drugProject/blob/branchProjectTrial0/SequenceModelToProjectDenemeHIV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, cohen_kappa_score, f1_score, confusion_matrix
import numpy as np

# %%
# data_path = '/content/data/HIV.csv'
# col_smiles = 'smiles'
# col_target = 'HIV_active'


# # read data
# df = pd.read_csv(data_path, sep=',')
# df_no_na = df[[col_smiles, col_target]].dropna()

# X = df_no_na[col_smiles]
# y = df_no_na[col_target].values

# print(X)

# %%
# col_smiles = 'canonical_smiles'
# col_target = 'bioactivity_class'

col_smiles = 'smiles'
col_target = 'HIV_active'


METRIC_ACCURACY = 'accuracy'
METRIC_F1_SCORE = 'f1-score'
METRIC_COHEN_KAPPA = 'Cohen kappa'
METRIC_CONFUSION_MATRIX = 'Confusion Matrix'


CLASSES = ['benign', 'malignant']
TEST_RATIO = 0.3
SEED = 0

#data_path = '/content/data/abl_kinase-data.csv'
#data_path = '/content/data/HIV.csv'
data_path = '/content/data/HIV.csv'

# %%
def read_data(data_path, col_smiles='smiles', col_target='HIV_active'):
    """Split original data into train data and test data.
    :param data_path: str, path to the a CSV data file
    :param col_smiles: str, name of smiles column
    :param col_target: str, name of target column
    :param test_ratio: float, proportion of the original data for testset, must be from 0 to 1
    :param seed: int, randomization seed for reproducibility
    :return (X, y)
    """
    

    # read data
    df = pd.read_csv(data_path, sep=',')
    df_no_na = df[[col_smiles, col_target]].dropna()

    X = df_no_na[col_smiles]
    y = df_no_na[col_target].values

    # df['new_Bio'] = pd.factorize(df.bioactivity_class)[0]

    # df.head()

    # y = df['new_Bio'].values

    return X, y

                
def get_prediction_score(y_label, y_predict):
    """Evaluate predictions using different evaluation metrics.
    :param y_label: list, contains true label
    :param y_predict: list, contains predicted label
    :return scores: dict, evaluation metrics on the prediction
    """
    scores = {}
    scores[METRIC_ACCURACY] = accuracy_score(y_label, y_predict)
    scores[METRIC_F1_SCORE] = f1_score(y_label, y_predict, labels=None, average='macro', sample_weight=None)
    scores[METRIC_COHEN_KAPPA] = cohen_kappa_score(y_label, y_predict)
    scores[METRIC_CONFUSION_MATRIX] = confusion_matrix(y_label, y_predict)
    
    return scores

# %%
import os
import sys
sys.path.insert(0, os.getcwd()) # add current working directory to pythonpath



import tensorflow as tf

from tensorflow.python.keras import backend as K
#os.environ["CUDA_VISIBLE_DEVICES"]="0" # Use only the 1st GPU
tf_config = tf.compat.v1.ConfigProto()
sess = tf.compat.v1.Session(config=tf_config)
K.set_session(sess)


from tensorflow.keras import callbacks
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Flatten
from tensorflow.keras.layers import Embedding, LSTM, GlobalMaxPooling1D, SpatialDropout1D, Conv1D, MaxPooling1D, GRU, Bidirectional
from tensorflow.keras import optimizers
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight


import warnings
import gc

# %%
# import os
# import sys
# sys.path.insert(0, os.getcwd()) # add current working directory to pythonpath



# import keras.backend as K
# import numpy as np
# import tensorflow as tf
# from keras import callbacks
# from keras.optimizers import Adam
# from keras.models import load_model
# from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
# from keras.models import Sequential
# from keras.models import Model
# from keras.layers import Input, Dense, Dropout, BatchNormalization, Flatten
# from keras.layers import Embedding, LSTM, GlobalMaxPooling1D, SpatialDropout1D, Conv1D, MaxPooling1D, GRU, Bidirectional
# from keras import optimizers
# from sklearn.model_selection import train_test_split
# from sklearn.utils import class_weight

# import warnings
# import argparse
# import gc

# %%
def generate_tokens(smiles, len_percentile=100):
    """
    Generate character tokens from smiles
    :param smiles: Pandas series, containing smiles
    :param len_percentile: percentile of smiles length to set as max length
    :return tokens
    :return num_words
    :return max_phrase_len
    """ 
    
    # Get max length of smiles
    smiles_len = smiles.apply(lambda p: len(p))
    max_phrase_len = int(np.percentile(smiles_len, len_percentile))
    print('True max length is ' + str(np.max(smiles_len)) + ', ' + str(max_phrase_len) + ' is set the length cutoff.')
        
    # Get unique words
    unique_words = np.unique(np.concatenate(smiles.apply(lambda p: np.array(list(p))).values, axis=0))
    num_words = len(unique_words)
    print('Vocab size is ' + str(num_words))
    
    tokenizer = Tokenizer(
        num_words = num_words,
        filters = '$',
        char_level = True,
        oov_token = '_'
    )

    #print(num_words)
    
    tokenizer.fit_on_texts(smiles)
    sequences = tokenizer.texts_to_sequences(smiles)
    tokens = pad_sequences(sequences, maxlen = max_phrase_len, padding='post', truncating='post')
    
    return tokens, num_words, max_phrase_len

# %%
smiles, y = read_data(data_path, col_smiles='smiles', col_target='HIV_active')
tokens, num_words, max_phrase_len = generate_tokens(smiles, len_percentile=100)
# Out:
# True max length is 580, 580 is set the length cutoff.
# Vocab size is 56

# %%
def create_model(model_type, num_words, input_length, output_dim=1, dropout_rate=0.0):
    """Build different sequence model
    :param model_type: str, can be 'cnn-gru', 'cnn', 'gru', 'lstm'
    :param num_words: int
    :param input_length: int
    :param output_dim: int
    :return model: Keras model
    """ 
    
    model = Sequential()
    if model_type == 'lstm': # LSTM - LSTM
        model.add(Embedding(num_words+1, 50, input_length=input_length))
        model.add(Bidirectional(LSTM(8, return_sequences=True)))
        model.add(Bidirectional(LSTM(16)))
        model.add(Dense(128, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(output_dim, activation='sigmoid'))
    elif model_type == 'gru': # GRU - GRU
        model.add(Embedding(num_words+1, 50, input_length=input_length))
        model.add(Bidirectional(GRU(8, return_sequences=True)))
        model.add(Bidirectional(GRU(16)))
        model.add(Dense(128, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(output_dim, activation='sigmoid'))
    elif model_type == 'cnn-gru': # 1D CNN - GRU
        model.add(Embedding(num_words+1, 50, input_length=input_length))
        model.add(Conv1D(8,3,activation='relu'))
        model.add(Bidirectional(GRU(16, return_sequences=True)))
        model.add(Bidirectional(GRU(32)))
        model.add(Dense(64, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(output_dim, activation='sigmoid'))
    elif model_type == 'cnn': # 1D CNN
        model.add(Embedding(num_words+1, 50, input_length=input_length))
        model.add(Conv1D(192, 10, activation='relu'))
        model.add(BatchNormalization())
        model.add(Conv1D(192, 3, activation='relu'))
        model.add(Flatten())
        model.add(Dense(128, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(output_dim, activation='sigmoid'))
    # elif model_type == 'cnn-lstm': # 1D CNN - LSTM
    #     model.add(Embedding(num_words+1, 50, input_length=input_length))
    #     model.add(Conv1D(192,3,activation='relu'))
    #     model.add(Bidirectional(LSTM(224, return_sequences=True)))
    #     model.add(Bidirectional(LSTM(384)))
    #     model.add(Dense(128, activation='relu'))
    #     model.add(Dropout(dropout_rate))
    #     model.add(Dense(output_dim, activation='sigmoid'))
    else:
        #raise ValueError(model_type + ' is not supported.')
        print('wrong model')
 
    model.summary()    
    return model

# %%
# def build_sequence_model(trainset, testset, model_type, num_words, input_length, output_dim=1, dropout_rate=0.0,
#                      batch_size=32, nb_epochs=100, lr=0.001):
#     """Train and evaluate CNN model
#     :param trainset: (X_train, y_train)
#     :param testset: (X_test, y_test)
#     :param model_type: str, can be 'cnn-gru', 'cnn', 'gru', 'lstm'
#     :param num_words: int
#     :param input_length: int
#     :param output_dim: int
#     :param batch_size: int, batch size for model training
#     :param nb_epochs: int, number of training epoches
#     :param lr: float, learning rate
#     :param save_path: path to save model
#     :return model: fitted Keras model
#     :return scores: dict, scores on test set for the fitted Keras model
#     """
    
#     # Create model
#     model = create_model(model_type=model_type, num_words=num_words, input_length=input_length, output_dim=output_dim,
#                          dropout_rate=dropout_rate)
    
#     # Callback list
#     callback_list = []
#     # monitor val_loss and terminate training if no improvement
#     early_stop = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.00001, \
#                 patience=20, verbose=2, mode='auto', restore_best_weights=True)
#     callback_list.append(early_stop)
    
#     # if save_path is not None:
#     #     # save best model based on val_acc during training
#     #     checkpoint = callbacks.ModelCheckpoint(os.path.join(save_path, '.h5'), monitor='val_acc', \
#     #                 verbose=0, save_best_only=True, save_weights_only=False, mode='auto')
#     #     callback_list.append(checkpoint)
        
#     # Get train and test set
#     (X_train, y_train) = trainset
#     (X_test, y_test) = testset
    
#     # Compute class weights
#     weight_list = class_weight.compute_class_weight('balanced', np.unique(y_train), y_train)
#     weight_dict = {}
#     for i in range(len(np.unique(y_train))):
#         weight_dict[np.unique(y_train)[i]] = weight_list[i]
    
#     # Train only classification head
#     optimizer = Adam(lr=lr, decay=1e-6, momentum=0.9, nesterov=True)
#     model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
#     model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=nb_epochs, \
#                         class_weight=weight_dict, callbacks=callback_list, verbose=2)
    
#     # Evaluate model    
#     prediction = model.predict(X_test)
#     y_val_predict = (prediction > 0.5).astype('uint8')
#     with warnings.catch_warnings():
#         warnings.simplefilter('ignore')  # disable the warning on f1-score with not all labels
#         scores = get_prediction_score(y_val, y_val_predict)
        
#     return model, scores

# %%
import matplotlib.pyplot as plt

# %%
def build_sequence_model(trainset, testset, model_type, num_words, input_length, output_dim=1, dropout_rate=0.0,
                     batch_size=32, nb_epochs=100, lr=0.001,
                     save_path=None):
    """Train and evaluate CNN model
    :param trainset: (X_train, y_train)
    :param testset: (X_test, y_test)
    :param model_type: str, can be 'cnn-gru', 'cnn', 'gru', 'lstm'
    :param num_words: int
    :param input_length: int
    :param output_dim: int
    :param batch_size: int, batch size for model training
    :param nb_epochs: int, number of training epoches
    :param lr: float, learning rate
    :param save_path: path to save model
    :return model: fitted Keras model
    :return scores: dict, scores on test set for the fitted Keras model
    """
    
    # Create model
    model = create_model(model_type=model_type, num_words=num_words, input_length=input_length, output_dim=output_dim,
                         dropout_rate=dropout_rate)
    
    # Callback list
    callback_list = []
    # monitor val_loss and terminate training if no improvement
    early_stop = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.00001, \
                patience=20, verbose=2, mode='auto', restore_best_weights=True)
    callback_list.append(early_stop)
    
    if save_path is not None:
        # save best model based on val_acc during training
        checkpoint = callbacks.ModelCheckpoint(os.path.join(save_path, model_type + '.h5'), monitor='val_acc', \
                    verbose=0, save_best_only=True, save_weights_only=False, mode='auto')
        callback_list.append(checkpoint)
        
    # Get train and test set
    (X_train, y_train) = trainset
    (X_test, y_test) = testset
    
    # Compute class weights
    weight_list = class_weight.compute_class_weight('balanced', np.unique(y_train), y_train)
    weight_dict = {}
    for i in range(len(np.unique(y_train))):
        weight_dict[np.unique(y_train)[i]] = weight_list[i]
    
    # Train only classification head
    optimizer = Adam(lr=lr, decay=1e-6)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=nb_epochs, \
                        class_weight=weight_dict, callbacks=callback_list, verbose=2)
    
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

        
    # Evaluate model    
    prediction = model.predict(X_test)
    y_val_predict = (prediction > 0.5).astype('uint8')
    y_val = y_test
    with warnings.catch_warnings():
        warnings.filterwarnings('ignore')  # disable the warning on f1-score with not all labels
        scores = get_prediction_score(y_val, y_val_predict)
        
    return model, scores

# %%
#data_path = '/content/data/abl_kinase-data.csv'
#data_path = '/content/data/HIV.csv'
data_path = '/content/data/HIV.csv'




#, 'cnn-gru', 'gru', 'lstm'
model_list = ['cnn', 'cnn-gru', 'gru', 'lstm']
batch_size = 16
nb_epochs = 100
lr = 0.001
save_path = '/content/data'

WORK_DIRECTORY = '/content/data'

# Make save_path
# if save_path is not None:
#     os.makedirs(os.path.join(save_path, 'sequence_models'), exist_ok=True)

# Read data
smiles, y = read_data(data_path, col_smiles='smiles', col_target='HIV_active')
tokens, num_words, max_phrase_len = generate_tokens(smiles, len_percentile=100)

# Get train and test set
X_train, X_test, y_train, y_test = train_test_split(tokens, y, test_size=TEST_RATIO, shuffle=True, stratify=y,
                                                  random_state=SEED)

# Build en evaluate graph models
model_scores = []
for model_type in model_list:
    model, scores = build_sequence_model((X_train, y_train), (X_test, y_test), model_type, num_words, max_phrase_len,
                                          output_dim=1, dropout_rate=0.0,
                                          batch_size=batch_size, nb_epochs=nb_epochs, lr=lr,
                             save_path=os.path.join(save_path, 'sequence_models', model_type + '.h5'))
    model_scores.append(scores)
        
    # force release memory
    K.clear_session()
    del model
    gc.collect()

model_df = pd.DataFrame({'model': model_list,

                    METRIC_ACCURACY: [score[METRIC_ACCURACY] for score in model_scores],
                    METRIC_F1_SCORE: [score[METRIC_F1_SCORE] for score in model_scores],
                    METRIC_COHEN_KAPPA: [score[METRIC_COHEN_KAPPA] for score in model_scores],
                    METRIC_CONFUSION_MATRIX: [score[METRIC_CONFUSION_MATRIX] for score in model_scores]                            
                      })
model_df = model_df[['model', METRIC_ACCURACY, METRIC_F1_SCORE, METRIC_COHEN_KAPPA,
                      METRIC_CONFUSION_MATRIX]]


model_df.to_csv(os.path.join(WORK_DIRECTORY, 'summary_sequence_model.csv'), index=False)
model_df.sort_values(by=[METRIC_ACCURACY, METRIC_F1_SCORE, METRIC_COHEN_KAPPA],
                      ascending=False, inplace=True)
print('Best model:\n' + str(model_df.iloc[0]))

print(model_df)



# !cp -r /content/data /content/drive/MyDrive/sequenceModelResults0

model_df.style.background_gradient(cmap='coolwarm',axis=0)

import seaborn as sns

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 23
plt.rcParams['figure.titlesize'] = 26
plt.rcParams['xtick.major.size'] = 10
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['ytick.major.size'] = 10
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.minor.size'] = 5
plt.rcParams['ytick.minor.width'] = 1
plt.rcParams['xtick.minor.size'] = 5
sns.set_style('ticks')


def normalized_confusion_matrix(y_test, conf_mat, model):
    _ , counts = np.unique(y_test,return_counts=True)
    conf_mat = (conf_mat.T/counts).T
    plt.figure(figsize=(6,5))
    ax=sns.heatmap(conf_mat,fmt='.2f',annot=True,annot_kws={'size':20},lw=2, cbar=True, cbar_kws={'label':'% Class accuracy'})
    plt.title(f'Confusion Matrix ({model})',size=22)
    plt.xticks(size=20)
    plt.yticks(size=20)
    ax.figure.axes[-1].yaxis.label.set_size(20) ##colorbar label
    cax = plt.gcf().axes[-1]  ##colorbar ticks
    cax.tick_params(labelsize=20) ## colorbar ticks
    plt.savefig(f'confusion-matrix-{model}.png',dpi=300)

i = 0
for score in model_scores:
  conf_mat = score[METRIC_CONFUSION_MATRIX]
  normalized_confusion_matrix(y_test,conf_mat, model_list[i])
  i = i + 1
# Out:
# True max length is 580, 580 is set the length cutoff.
# Vocab size is 56
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 580, 50)           2850
# _________________________________________________________________
# conv1d (Conv1D)              (None, 571, 192)          96192
# _________________________________________________________________
# batch_normalization (BatchNo (None, 571, 192)          768
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 569, 192)          110784
# _________________________________________________________________
# flatten (Flatten)            (None, 109248)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               13983872
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 14,194,595
# Trainable params: 14,194,211
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 900/900 - 49s - loss: 0.7119 - accuracy: 0.4395 - val_loss: 0.6930 - val_accuracy: 0.9649
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 900/900 - 16s - loss: 0.6933 - accuracy: 0.5582 - val_loss: 0.6908 - val_accuracy: 0.9649
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 900/900 - 16s - loss: 0.6933 - accuracy: 0.4511 - val_loss: 0.6934 - val_accuracy: 0.0351
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 900/900 - 16s - loss: 0.6932 - accuracy: 0.4298 - val_loss: 0.6928 - val_accuracy: 0.9649
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 900/900 - 16s - loss: 0.6932 - accuracy: 0.0838 - val_loss: 0.6881 - val_accuracy: 0.9649
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 900/900 - 16s - loss: 0.6933 - accuracy: 0.5727 - val_loss: 0.6881 - val_accuracy: 0.9649
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 900/900 - 16s - loss: 0.6933 - accuracy: 0.6249 - val_loss: 0.6905 - val_accuracy: 0.9649
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 900/900 - 16s - loss: 0.6932 - accuracy: 0.3167 - val_loss: 0.6861 - val_accuracy: 0.9649
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 900/900 - 16s - loss: 0.6933 - accuracy: 0.7881 - val_loss: 0.6869 - val_accuracy: 0.9649
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 900/900 - 16s - loss: 0.6933 - accuracy: 0.7907 - val_loss: 0.6900 - val_accuracy: 0.9649
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 900/900 - 16s - loss: 0.6933 - accuracy: 0.4405 - val_loss: 0.6883 - val_accuracy: 0.9649
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 900/900 - 16s - loss: 0.6933 - accuracy: 0.6544 - val_loss: 0.6904 - val_accuracy: 0.9649
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 900/900 - 16s - loss: 0.6932 - accuracy: 0.7771 - val_loss: 0.6919 - val_accuracy: 0.9649
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 900/900 - 16s - loss: 0.6932 - accuracy: 0.4398 - val_loss: 0.6937 - val_accuracy: 0.0351
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 900/900 - 16s - loss: 0.6932 - accuracy: 0.1334 - val_loss: 0.6922 - val_accuracy: 0.9649
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 900/900 - 16s - loss: 0.6933 - accuracy: 0.7345 - val_loss: 0.6933 - val_accuracy: 0.0351
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 900/900 - 16s - loss: 0.6932 - accuracy: 0.6039 - val_loss: 0.6923 - val_accuracy: 0.9649
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 900/900 - 16s - loss: 0.6933 - accuracy: 0.6414 - val_loss: 0.6946 - val_accuracy: 0.0351
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 900/900 - 16s - loss: 0.6932 - accuracy: 0.1855 - val_loss: 0.6932 - val_accuracy: 0.0351
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 900/900 - 16s - loss: 0.6932 - accuracy: 0.9264 - val_loss: 0.6968 - val_accuracy: 0.0351
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 900/900 - 16s - loss: 0.6932 - accuracy: 0.0779 - val_loss: 0.6936 - val_accuracy: 0.0351
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 900/900 - 16s - loss: 0.6933 - accuracy: 0.6757 - val_loss: 0.6929 - val_accuracy: 0.9649
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 900/900 - 16s - loss: 0.6932 - accuracy: 0.5400 - val_loss: 0.6933 - val_accuracy: 0.0351
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# 900/900 - 16s - loss: 0.6932 - accuracy: 0.6108 - val_loss: 0.6965 - val_accuracy: 0.0351
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# 900/900 - 16s - loss: 0.6933 - accuracy: 0.2177 - val_loss: 0.6949 - val_accuracy: 0.0351
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# 900/900 - 16s - loss: 0.6933 - accuracy: 0.3622 - val_loss: 0.6944 - val_accuracy: 0.0351
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/100
# 900/900 - 16s - loss: 0.6932 - accuracy: 0.0547 - val_loss: 0.6911 - val_accuracy: 0.9649
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/100
# 900/900 - 16s - loss: 0.6932 - accuracy: 0.5759 - val_loss: 0.6917 - val_accuracy: 0.9649
# Restoring model weights from the end of the best epoch.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00028: early stopping
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 580, 50)           2850
# _________________________________________________________________
# conv1d (Conv1D)              (None, 578, 8)            1208
# _________________________________________________________________
# bidirectional (Bidirectional (None, 578, 32)           2496
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                12672
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 23,451
# Trainable params: 23,451
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 900/900 - 67s - loss: 0.6941 - accuracy: 0.6577 - val_loss: 0.6754 - val_accuracy: 0.9253
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 900/900 - 61s - loss: 0.6869 - accuracy: 0.4754 - val_loss: 0.7166 - val_accuracy: 0.2696
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 900/900 - 61s - loss: 0.6696 - accuracy: 0.6124 - val_loss: 0.6938 - val_accuracy: 0.6756
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 900/900 - 60s - loss: 0.6554 - accuracy: 0.7425 - val_loss: 0.6422 - val_accuracy: 0.7574
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 900/900 - 60s - loss: 0.6457 - accuracy: 0.7292 - val_loss: 0.6750 - val_accuracy: 0.6613
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 900/900 - 61s - loss: 0.6316 - accuracy: 0.7443 - val_loss: 0.5934 - val_accuracy: 0.7543
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 900/900 - 60s - loss: 0.6017 - accuracy: 0.7668 - val_loss: 0.4536 - val_accuracy: 0.9053
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 900/900 - 60s - loss: 0.5834 - accuracy: 0.8056 - val_loss: 0.6780 - val_accuracy: 0.7309
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 900/900 - 60s - loss: 0.5730 - accuracy: 0.8009 - val_loss: 0.5326 - val_accuracy: 0.8272
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 900/900 - 60s - loss: 0.5674 - accuracy: 0.7922 - val_loss: 0.5316 - val_accuracy: 0.8074
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 900/900 - 61s - loss: 0.5578 - accuracy: 0.7880 - val_loss: 0.5263 - val_accuracy: 0.8061
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 900/900 - 60s - loss: 0.5495 - accuracy: 0.8041 - val_loss: 0.6923 - val_accuracy: 0.6674
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 900/900 - 60s - loss: 0.5404 - accuracy: 0.7977 - val_loss: 0.5408 - val_accuracy: 0.8231
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 900/900 - 60s - loss: 0.5314 - accuracy: 0.8146 - val_loss: 0.5503 - val_accuracy: 0.7731
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 900/900 - 62s - loss: 0.5235 - accuracy: 0.8095 - val_loss: 0.5652 - val_accuracy: 0.7427
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 900/900 - 61s - loss: 0.5157 - accuracy: 0.8075 - val_loss: 0.5021 - val_accuracy: 0.7913
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 900/900 - 60s - loss: 0.5044 - accuracy: 0.8215 - val_loss: 0.4883 - val_accuracy: 0.8301
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 900/900 - 60s - loss: 0.5087 - accuracy: 0.8137 - val_loss: 0.4348 - val_accuracy: 0.8519
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 900/900 - 60s - loss: 0.4924 - accuracy: 0.8241 - val_loss: 0.3232 - val_accuracy: 0.9193
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 900/900 - 61s - loss: 0.4881 - accuracy: 0.8108 - val_loss: 0.4867 - val_accuracy: 0.8066
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 900/900 - 62s - loss: 0.4806 - accuracy: 0.8129 - val_loss: 0.4720 - val_accuracy: 0.7877
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 900/900 - 61s - loss: 0.4605 - accuracy: 0.8109 - val_loss: 0.4657 - val_accuracy: 0.7998
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 900/900 - 61s - loss: 0.4610 - accuracy: 0.8267 - val_loss: 0.4127 - val_accuracy: 0.8574
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# 900/900 - 60s - loss: 0.4501 - accuracy: 0.8219 - val_loss: 0.6002 - val_accuracy: 0.7133
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# 900/900 - 60s - loss: 0.4347 - accuracy: 0.8311 - val_loss: 0.4951 - val_accuracy: 0.7896
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# 900/900 - 60s - loss: 0.4270 - accuracy: 0.8236 - val_loss: 0.4361 - val_accuracy: 0.8220
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/100
# 900/900 - 60s - loss: 0.4832 - accuracy: 0.7828 - val_loss: 0.6207 - val_accuracy: 0.7105
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/100
# 900/900 - 60s - loss: 0.4801 - accuracy: 0.7724 - val_loss: 0.4522 - val_accuracy: 0.8173
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/100
# 900/900 - 60s - loss: 0.4173 - accuracy: 0.8317 - val_loss: 0.4760 - val_accuracy: 0.7824
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/100
# 900/900 - 60s - loss: 0.4397 - accuracy: 0.8114 - val_loss: 0.4750 - val_accuracy: 0.7812
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 31/100
# 900/900 - 60s - loss: 0.3969 - accuracy: 0.8298 - val_loss: 0.3903 - val_accuracy: 0.8394
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 32/100
# 900/900 - 60s - loss: 0.3850 - accuracy: 0.8185 - val_loss: 0.5018 - val_accuracy: 0.7532
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 33/100
# 900/900 - 60s - loss: 0.4153 - accuracy: 0.7996 - val_loss: 0.5003 - val_accuracy: 0.7056
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 34/100
# 900/900 - 60s - loss: 0.5129 - accuracy: 0.7444 - val_loss: 0.5453 - val_accuracy: 0.7425
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 35/100
# 900/900 - 60s - loss: 0.4348 - accuracy: 0.8008 - val_loss: 0.4101 - val_accuracy: 0.8272
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 36/100
# 900/900 - 60s - loss: 0.4002 - accuracy: 0.8090 - val_loss: 0.4575 - val_accuracy: 0.7788
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 37/100
# 900/900 - 60s - loss: 0.3783 - accuracy: 0.8059 - val_loss: 0.3566 - val_accuracy: 0.8425
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 38/100
# 900/900 - 60s - loss: 0.3628 - accuracy: 0.8057 - val_loss: 0.4371 - val_accuracy: 0.7824
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 39/100
# 900/900 - 60s - loss: 0.3429 - accuracy: 0.8234 - val_loss: 0.5746 - val_accuracy: 0.7272
# Restoring model weights from the end of the best epoch.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00039: early stopping
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 580, 50)           2850
# _________________________________________________________________
# bidirectional (Bidirectional (None, 580, 16)           2880
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 32)                3264
# _________________________________________________________________
# dense (Dense)                (None, 128)               4224
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 13,347
# Trainable params: 13,347
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 900/900 - 63s - loss: 0.6941 - accuracy: 0.5901 - val_loss: 0.7125 - val_accuracy: 0.0410
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 900/900 - 57s - loss: 0.6923 - accuracy: 0.3947 - val_loss: 0.6718 - val_accuracy: 0.6414
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 900/900 - 57s - loss: 0.6855 - accuracy: 0.5132 - val_loss: 0.6835 - val_accuracy: 0.5670
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 900/900 - 57s - loss: 0.6791 - accuracy: 0.5812 - val_loss: 0.6594 - val_accuracy: 0.6199
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 900/900 - 57s - loss: 0.6726 - accuracy: 0.6118 - val_loss: 0.7806 - val_accuracy: 0.3645
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 900/900 - 56s - loss: 0.6680 - accuracy: 0.6136 - val_loss: 0.6230 - val_accuracy: 0.7128
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 900/900 - 57s - loss: 0.6613 - accuracy: 0.6472 - val_loss: 0.6973 - val_accuracy: 0.6257
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 900/900 - 57s - loss: 0.6530 - accuracy: 0.6656 - val_loss: 0.6022 - val_accuracy: 0.7439
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 900/900 - 57s - loss: 0.6368 - accuracy: 0.6889 - val_loss: 0.8782 - val_accuracy: 0.4768
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 900/900 - 57s - loss: 0.6178 - accuracy: 0.7678 - val_loss: 0.7475 - val_accuracy: 0.6657
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 900/900 - 57s - loss: 0.5970 - accuracy: 0.7959 - val_loss: 0.5547 - val_accuracy: 0.8232
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 900/900 - 57s - loss: 0.5834 - accuracy: 0.8096 - val_loss: 0.6338 - val_accuracy: 0.7573
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 900/900 - 57s - loss: 0.5740 - accuracy: 0.8048 - val_loss: 0.5068 - val_accuracy: 0.8494
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 900/900 - 57s - loss: 0.5618 - accuracy: 0.8196 - val_loss: 0.7503 - val_accuracy: 0.6446
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 900/900 - 57s - loss: 0.5523 - accuracy: 0.8104 - val_loss: 0.4365 - val_accuracy: 0.8782
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 900/900 - 57s - loss: 0.5467 - accuracy: 0.8212 - val_loss: 0.4993 - val_accuracy: 0.8578
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 900/900 - 57s - loss: 0.5406 - accuracy: 0.8229 - val_loss: 0.5195 - val_accuracy: 0.8294
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 900/900 - 56s - loss: 0.5342 - accuracy: 0.8214 - val_loss: 0.5201 - val_accuracy: 0.8192
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 900/900 - 57s - loss: 0.5249 - accuracy: 0.8289 - val_loss: 0.5831 - val_accuracy: 0.7761
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 900/900 - 57s - loss: 0.5246 - accuracy: 0.8221 - val_loss: 0.5694 - val_accuracy: 0.7919
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 900/900 - 56s - loss: 0.5138 - accuracy: 0.8282 - val_loss: 0.4942 - val_accuracy: 0.8343
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 900/900 - 57s - loss: 0.5027 - accuracy: 0.8387 - val_loss: 0.4967 - val_accuracy: 0.8309
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 900/900 - 57s - loss: 0.4973 - accuracy: 0.8315 - val_loss: 0.3895 - val_accuracy: 0.8887
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# 900/900 - 58s - loss: 0.4863 - accuracy: 0.8355 - val_loss: 0.5135 - val_accuracy: 0.8197
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# 900/900 - 57s - loss: 0.4836 - accuracy: 0.8340 - val_loss: 0.3771 - val_accuracy: 0.8828
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# 900/900 - 57s - loss: 0.4752 - accuracy: 0.8462 - val_loss: 0.5547 - val_accuracy: 0.7912
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/100
# 900/900 - 57s - loss: 0.4667 - accuracy: 0.8370 - val_loss: 0.5067 - val_accuracy: 0.8174
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/100
# 900/900 - 57s - loss: 0.4636 - accuracy: 0.8410 - val_loss: 0.5943 - val_accuracy: 0.7583
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/100
# 900/900 - 57s - loss: 0.4637 - accuracy: 0.8457 - val_loss: 0.4598 - val_accuracy: 0.8444
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/100
# 900/900 - 57s - loss: 0.4541 - accuracy: 0.8424 - val_loss: 0.4091 - val_accuracy: 0.8583
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 31/100
# 900/900 - 57s - loss: 0.4443 - accuracy: 0.8473 - val_loss: 0.5202 - val_accuracy: 0.8041
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 32/100
# 900/900 - 57s - loss: 0.4428 - accuracy: 0.8473 - val_loss: 0.4179 - val_accuracy: 0.8595
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 33/100
# 900/900 - 57s - loss: 0.4311 - accuracy: 0.8545 - val_loss: 0.4841 - val_accuracy: 0.8336
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 34/100
# 900/900 - 57s - loss: 0.4220 - accuracy: 0.8604 - val_loss: 0.4465 - val_accuracy: 0.8480
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 35/100
# 900/900 - 57s - loss: 0.4261 - accuracy: 0.8491 - val_loss: 0.4721 - val_accuracy: 0.8308
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 36/100
# 900/900 - 56s - loss: 0.4100 - accuracy: 0.8559 - val_loss: 0.4382 - val_accuracy: 0.8466
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 37/100
# 900/900 - 56s - loss: 0.4040 - accuracy: 0.8647 - val_loss: 0.4684 - val_accuracy: 0.8254
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 38/100
# 900/900 - 56s - loss: 0.4056 - accuracy: 0.8561 - val_loss: 0.6511 - val_accuracy: 0.7083
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 39/100
# 900/900 - 56s - loss: 0.3975 - accuracy: 0.8565 - val_loss: 0.5790 - val_accuracy: 0.7759
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 40/100
# 900/900 - 57s - loss: 0.3959 - accuracy: 0.8526 - val_loss: 0.4307 - val_accuracy: 0.8446
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 41/100
# 900/900 - 56s - loss: 0.3865 - accuracy: 0.8632 - val_loss: 0.4289 - val_accuracy: 0.8415
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 42/100
# 900/900 - 56s - loss: 0.3756 - accuracy: 0.8614 - val_loss: 0.3951 - val_accuracy: 0.8532
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 43/100
# 900/900 - 56s - loss: 0.3745 - accuracy: 0.8649 - val_loss: 0.5019 - val_accuracy: 0.8059
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 44/100
# 900/900 - 58s - loss: 0.3952 - accuracy: 0.8403 - val_loss: 0.5826 - val_accuracy: 0.7074
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 45/100
# 900/900 - 58s - loss: 0.4154 - accuracy: 0.8314 - val_loss: 0.4189 - val_accuracy: 0.8476
# Restoring model weights from the end of the best epoch.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00045: early stopping
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 580, 50)           2850
# _________________________________________________________________
# bidirectional (Bidirectional (None, 580, 16)           3776
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 32)                4224
# _________________________________________________________________
# dense (Dense)                (None, 128)               4224
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 15,203
# Trainable params: 15,203
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 900/900 - 64s - loss: 0.6940 - accuracy: 0.5822 - val_loss: 0.7059 - val_accuracy: 0.0781
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 900/900 - 57s - loss: 0.6920 - accuracy: 0.3912 - val_loss: 0.7018 - val_accuracy: 0.1590
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 900/900 - 57s - loss: 0.6737 - accuracy: 0.5246 - val_loss: 0.8749 - val_accuracy: 0.5160
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 900/900 - 57s - loss: 0.6289 - accuracy: 0.7586 - val_loss: 0.6733 - val_accuracy: 0.7597
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 900/900 - 57s - loss: 0.6157 - accuracy: 0.7365 - val_loss: 0.5498 - val_accuracy: 0.7504
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 900/900 - 57s - loss: 0.6127 - accuracy: 0.6932 - val_loss: 0.7988 - val_accuracy: 0.5558
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 900/900 - 57s - loss: 0.5990 - accuracy: 0.6914 - val_loss: 0.5387 - val_accuracy: 0.7698
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 900/900 - 57s - loss: 0.5878 - accuracy: 0.7174 - val_loss: 0.6438 - val_accuracy: 0.6433
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 900/900 - 57s - loss: 0.5769 - accuracy: 0.7460 - val_loss: 0.6788 - val_accuracy: 0.6122
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 900/900 - 57s - loss: 0.5807 - accuracy: 0.7200 - val_loss: 0.5321 - val_accuracy: 0.7532
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 900/900 - 57s - loss: 0.5665 - accuracy: 0.7471 - val_loss: 0.4808 - val_accuracy: 0.7963
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 900/900 - 57s - loss: 0.5575 - accuracy: 0.7798 - val_loss: 0.5567 - val_accuracy: 0.7452
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 900/900 - 57s - loss: 0.5628 - accuracy: 0.7754 - val_loss: 0.6433 - val_accuracy: 0.7332
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 900/900 - 57s - loss: 0.5561 - accuracy: 0.7738 - val_loss: 0.6258 - val_accuracy: 0.7363
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 900/900 - 57s - loss: 0.5580 - accuracy: 0.7887 - val_loss: 0.5505 - val_accuracy: 0.7563
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 900/900 - 58s - loss: 0.5471 - accuracy: 0.7899 - val_loss: 0.5612 - val_accuracy: 0.7582
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 900/900 - 57s - loss: 0.5430 - accuracy: 0.7833 - val_loss: 0.5092 - val_accuracy: 0.7967
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 900/900 - 57s - loss: 0.5352 - accuracy: 0.7773 - val_loss: 0.5977 - val_accuracy: 0.6928
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 900/900 - 57s - loss: 0.5278 - accuracy: 0.7890 - val_loss: 0.5330 - val_accuracy: 0.7663
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 900/900 - 57s - loss: 0.5242 - accuracy: 0.8045 - val_loss: 0.4798 - val_accuracy: 0.8445
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 900/900 - 58s - loss: 0.5279 - accuracy: 0.7971 - val_loss: 0.5505 - val_accuracy: 0.7650
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 900/900 - 57s - loss: 0.5160 - accuracy: 0.8038 - val_loss: 0.5392 - val_accuracy: 0.7888
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 900/900 - 57s - loss: 0.5185 - accuracy: 0.8008 - val_loss: 0.4817 - val_accuracy: 0.8181
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# 900/900 - 58s - loss: 0.5098 - accuracy: 0.8125 - val_loss: 0.5109 - val_accuracy: 0.7730
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# 900/900 - 58s - loss: 0.5048 - accuracy: 0.8107 - val_loss: 0.7868 - val_accuracy: 0.6672
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# 900/900 - 57s - loss: 0.5108 - accuracy: 0.8010 - val_loss: 0.5142 - val_accuracy: 0.8232
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/100
# 900/900 - 57s - loss: 0.4979 - accuracy: 0.8160 - val_loss: 0.4024 - val_accuracy: 0.8546
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/100
# 900/900 - 57s - loss: 0.4938 - accuracy: 0.8363 - val_loss: 0.4680 - val_accuracy: 0.8198
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/100
# 900/900 - 57s - loss: 0.4915 - accuracy: 0.8212 - val_loss: 0.4934 - val_accuracy: 0.8075
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/100
# 900/900 - 57s - loss: 0.4927 - accuracy: 0.8159 - val_loss: 0.4788 - val_accuracy: 0.8049
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 31/100
# 900/900 - 57s - loss: 0.4855 - accuracy: 0.8261 - val_loss: 0.5393 - val_accuracy: 0.7645
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 32/100
# 900/900 - 57s - loss: 0.4828 - accuracy: 0.8231 - val_loss: 0.4796 - val_accuracy: 0.8271
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 33/100
# 900/900 - 57s - loss: 0.4937 - accuracy: 0.8187 - val_loss: 0.6168 - val_accuracy: 0.7125
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 34/100
# 900/900 - 57s - loss: 0.4853 - accuracy: 0.8285 - val_loss: 0.4338 - val_accuracy: 0.8641
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 35/100
# 900/900 - 58s - loss: 0.4693 - accuracy: 0.8424 - val_loss: 0.4837 - val_accuracy: 0.8378
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 36/100
# 900/900 - 57s - loss: 0.4688 - accuracy: 0.8372 - val_loss: 0.5008 - val_accuracy: 0.8117
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 37/100
# 900/900 - 57s - loss: 0.4650 - accuracy: 0.8396 - val_loss: 0.4850 - val_accuracy: 0.8276
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 38/100
# 900/900 - 57s - loss: 0.4655 - accuracy: 0.8427 - val_loss: 0.4594 - val_accuracy: 0.8159
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 39/100
# 900/900 - 57s - loss: 0.4584 - accuracy: 0.8430 - val_loss: 0.5616 - val_accuracy: 0.7861
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 40/100
# 900/900 - 57s - loss: 0.4617 - accuracy: 0.8440 - val_loss: 0.5355 - val_accuracy: 0.8189
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 41/100
# 900/900 - 57s - loss: 0.4552 - accuracy: 0.8329 - val_loss: 0.4208 - val_accuracy: 0.8710
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 42/100
# 900/900 - 58s - loss: 0.4563 - accuracy: 0.8393 - val_loss: 0.5288 - val_accuracy: 0.8130
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 43/100
# 900/900 - 57s - loss: 0.4474 - accuracy: 0.8543 - val_loss: 0.4843 - val_accuracy: 0.8295
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 44/100
# 900/900 - 57s - loss: 0.4462 - accuracy: 0.8462 - val_loss: 0.5108 - val_accuracy: 0.8018
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 45/100
# 900/900 - 57s - loss: 0.4371 - accuracy: 0.8554 - val_loss: 0.4687 - val_accuracy: 0.8242
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 46/100
# 900/900 - 57s - loss: 0.4275 - accuracy: 0.8509 - val_loss: 0.4173 - val_accuracy: 0.8515
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 47/100
# 900/900 - 58s - loss: 0.4492 - accuracy: 0.8253 - val_loss: 0.4744 - val_accuracy: 0.8302
# Restoring model weights from the end of the best epoch.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00047: early stopping
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# Best model:
# model                                  cnn
# accuracy                          0.964908
# f1-score                           0.49107
# Cohen kappa                              0
# Confusion Matrix    [[11906, 0], [433, 0]]
# Name: 0, dtype: object
#      model  accuracy  f1-score  Cohen kappa             Confusion Matrix
# 0      cnn  0.964908  0.491070     0.000000       [[11906, 0], [433, 0]]
# 1  cnn-gru  0.919280  0.630812     0.268661   [[11125, 781], [215, 218]]
# 2      gru  0.882811  0.585733     0.191158  [[10671, 1235], [211, 222]]
# 3     lstm  0.854607  0.567892     0.168601  [[10298, 1608], [186, 247]]
# cp: cannot create directory '/content/drive/MyDrive/sequenceModelResults0': No such file or directory

# %%
model_df.style.background_gradient(cmap='coolwarm',axis=0)
# Out:
# <style  type="text/css" >
# #T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row0_col1,#T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row1_col2,#T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row1_col3{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row0_col2,#T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row0_col3,#T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row3_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row1_col1{
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }#T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row2_col1{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row2_col2{
#             background-color:  #f7b497;
#             color:  #000000;
#         }#T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row2_col3{
#             background-color:  #f7a889;
#             color:  #000000;
#         }#T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row3_col2{
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }#T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row3_col3{
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }</style><table id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model</th>        <th class="col_heading level0 col1" >accuracy</th>        <th class="col_heading level0 col2" >f1-score</th>        <th class="col_heading level0 col3" >Cohen kappa</th>        <th class="col_heading level0 col4" >Confusion Matrix</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row0_col0" class="data row0 col0" >cnn</td>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row0_col1" class="data row0 col1" >0.964908</td>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row0_col2" class="data row0 col2" >0.491070</td>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row0_col3" class="data row0 col3" >0.000000</td>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row0_col4" class="data row0 col4" >[[11906     0]
#  [  433     0]]</td>
#             </tr>
#             <tr>
#                         <th id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row1_col0" class="data row1 col0" >cnn-gru</td>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row1_col1" class="data row1 col1" >0.919280</td>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row1_col2" class="data row1 col2" >0.630812</td>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row1_col3" class="data row1 col3" >0.268661</td>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row1_col4" class="data row1 col4" >[[11125   781]
#  [  215   218]]</td>
#             </tr>
#             <tr>
#                         <th id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row2_col0" class="data row2 col0" >gru</td>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row2_col1" class="data row2 col1" >0.882811</td>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row2_col2" class="data row2 col2" >0.585733</td>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row2_col3" class="data row2 col3" >0.191158</td>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row2_col4" class="data row2 col4" >[[10671  1235]
#  [  211   222]]</td>
#             </tr>
#             <tr>
#                         <th id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row3_col0" class="data row3 col0" >lstm</td>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row3_col1" class="data row3 col1" >0.854607</td>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row3_col2" class="data row3 col2" >0.567892</td>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row3_col3" class="data row3 col3" >0.168601</td>
#                         <td id="T_9cf3ccfc_b98b_11eb_9341_0242ac1c0002row3_col4" class="data row3 col4" >[[10298  1608]
#  [  186   247]]</td>
#             </tr>
#     </tbody></table>

# %%
import seaborn as sns

# %%
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 23
plt.rcParams['figure.titlesize'] = 26
plt.rcParams['xtick.major.size'] = 10
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['ytick.major.size'] = 10
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.minor.size'] = 5
plt.rcParams['ytick.minor.width'] = 1
plt.rcParams['xtick.minor.size'] = 5
sns.set_style('ticks')

# %%
def normalized_confusion_matrix(y_test, conf_mat, model):
    _ , counts = np.unique(y_test,return_counts=True)
    conf_mat = (conf_mat.T/counts).T
    plt.figure(figsize=(6,5))
    ax=sns.heatmap(conf_mat,fmt='.2f',annot=True,annot_kws={'size':20},lw=2, cbar=True, cbar_kws={'label':'% Class accuracy'})
    plt.title(f'Confusion Matrix ({model})',size=22)
    plt.xticks(size=20)
    plt.yticks(size=20)
    ax.figure.axes[-1].yaxis.label.set_size(20) ##colorbar label
    cax = plt.gcf().axes[-1]  ##colorbar ticks
    cax.tick_params(labelsize=20) ## colorbar ticks
    plt.savefig(f'confusion-matrix-{model}.png',dpi=300)

# %%
i = 0
for score in model_scores:
  conf_mat = score[METRIC_CONFUSION_MATRIX]
  normalized_confusion_matrix(y_test,conf_mat, model_list[i])
  i = i + 1
